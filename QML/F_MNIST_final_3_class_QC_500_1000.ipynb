# %%
# !pip install tensorflow==2.15.0
# !pip install tensorflow-quantum==0.7.3
# Out:
# Collecting tensorflow==2.15.0
#   Downloading tensorflow-2.15.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.4 kB)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (24.12.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (3.12.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (18.1.1)
# Collecting ml-dtypes~=0.2.0 (from tensorflow==2.15.0)
#   Downloading ml_dtypes-0.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (1.26.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (4.25.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (4.12.2)
# Collecting wrapt<1.15,>=1.11.0 (from tensorflow==2.15.0)
#   Downloading wrapt-1.14.1-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (0.37.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (1.69.0)
# Collecting tensorboard<2.16,>=2.15 (from tensorflow==2.15.0)
#   Downloading tensorboard-2.15.2-py3-none-any.whl.metadata (1.7 kB)
# Collecting tensorflow-estimator<2.16,>=2.15.0 (from tensorflow==2.15.0)
#   Downloading tensorflow_estimator-2.15.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting keras<2.16,>=2.15.0 (from tensorflow==2.15.0)
#   Downloading keras-2.15.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow==2.15.0) (0.45.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (1.2.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.7)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.1.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (2024.12.14)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.0.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.2.2)
# Downloading tensorflow-2.15.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (475.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 475.3/475.3 MB 2.2 MB/s eta 0:00:00
# Downloading keras-2.15.0-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 36.0 MB/s eta 0:00:00
# Downloading ml_dtypes-0.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 34.6 MB/s eta 0:00:00
# Downloading tensorboard-2.15.2-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 51.3 MB/s eta 0:00:00
# Downloading tensorflow_estimator-2.15.0-py2.py3-none-any.whl (441 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.0/442.0 kB 21.7 MB/s eta 0:00:00
# Downloading wrapt-1.14.1-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 kB 4.8 MB/s eta 0:00:00
# Installing collected packages: wrapt, tensorflow-estimator, ml-dtypes, keras, tensorboard, tensorflow
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.17.0
#     Uninstalling wrapt-1.17.0:
#       Successfully uninstalled wrapt-1.17.0
#   Attempting uninstall: ml-dtypes
#     Found existing installation: ml-dtypes 0.4.1
#     Uninstalling ml-dtypes-0.4.1:
#       Successfully uninstalled ml-dtypes-0.4.1
#   Attempting uninstall: keras
#     Found existing installation: keras 3.5.0
#     Uninstalling keras-3.5.0:
#       Successfully uninstalled keras-3.5.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.17.1
#     Uninstalling tensorboard-2.17.1:
#       Successfully uninstalled tensorboard-2.17.1
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.17.1
#     Uninstalling tensorflow-2.17.1:
#       Successfully uninstalled tensorflow-2.17.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorstore 0.1.71 requires ml_dtypes>=0.3.1, but you have ml-dtypes 0.2.0 which is incompatible.
# tf-keras 2.17.0 requires tensorflow<2.18,>=2.17, but you have tensorflow 2.15.0 which is incompatible.
# Successfully installed keras-2.15.0 ml-dtypes-0.2.0 tensorboard-2.15.2 tensorflow-2.15.0 tensorflow-estimator-2.15.0 wrapt-1.14.1
# Collecting tensorflow-quantum==0.7.3
#   Downloading tensorflow_quantum-0.7.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.7 kB)
# Collecting cirq-core==1.3.0 (from tensorflow-quantum==0.7.3)
#   Downloading cirq_core-1.3.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting cirq-google==1.3.0 (from tensorflow-quantum==0.7.3)
#   Downloading cirq_google-1.3.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting sympy==1.12 (from tensorflow-quantum==0.7.3)
#   Downloading sympy-1.12-py3-none-any.whl.metadata (12 kB)
# Collecting duet~=0.2.8 (from cirq-core==1.3.0->tensorflow-quantum==0.7.3)
#   Downloading duet-0.2.9-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: matplotlib~=3.0 in /usr/local/lib/python3.11/dist-packages (from cirq-core==1.3.0->tensorflow-quantum==0.7.3) (3.10.0)
# Requirement already satisfied: networkx>=2.4 in /usr/local/lib/python3.11/dist-packages (from cirq-core==1.3.0->tensorflow-quantum==0.7.3) (3.4.2)
# Requirement already satisfied: numpy~=1.16 in /usr/local/lib/python3.11/dist-packages (from cirq-core==1.3.0->tensorflow-quantum==0.7.3) (1.26.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from cirq-core==1.3.0->tensorflow-quantum==0.7.3) (2.2.2)
# Collecting sortedcontainers~=2.0 (from cirq-core==1.3.0->tensorflow-quantum==0.7.3)
#   Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from cirq-core==1.3.0->tensorflow-quantum==0.7.3) (1.13.1)
# Requirement already satisfied: typing-extensions>=4.2 in /usr/local/lib/python3.11/dist-packages (from cirq-core==1.3.0->tensorflow-quantum==0.7.3) (4.12.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from cirq-core==1.3.0->tensorflow-quantum==0.7.3) (4.67.1)
# Requirement already satisfied: google-api-core>=1.14.0 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]>=1.14.0->cirq-google==1.3.0->tensorflow-quantum==0.7.3) (2.19.2)
# Requirement already satisfied: proto-plus>=1.20.0 in /usr/local/lib/python3.11/dist-packages (from cirq-google==1.3.0->tensorflow-quantum==0.7.3) (1.25.0)
# Requirement already satisfied: protobuf>=3.15.0 in /usr/local/lib/python3.11/dist-packages (from cirq-google==1.3.0->tensorflow-quantum==0.7.3) (4.25.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.11/dist-packages (from sympy==1.12->tensorflow-quantum==0.7.3) (1.3.0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core>=1.14.0->google-api-core[grpc]>=1.14.0->cirq-google==1.3.0->tensorflow-quantum==0.7.3) (1.66.0)
# Requirement already satisfied: google-auth<3.0.dev0,>=2.14.1 in /usr/local/lib/python3.11/dist-packages (from google-api-core>=1.14.0->google-api-core[grpc]>=1.14.0->cirq-google==1.3.0->tensorflow-quantum==0.7.3) (2.27.0)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /usr/local/lib/python3.11/dist-packages (from google-api-core>=1.14.0->google-api-core[grpc]>=1.14.0->cirq-google==1.3.0->tensorflow-quantum==0.7.3) (2.32.3)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]>=1.14.0->cirq-google==1.3.0->tensorflow-quantum==0.7.3) (1.69.0)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]>=1.14.0->cirq-google==1.3.0->tensorflow-quantum==0.7.3) (1.62.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib~=3.0->cirq-core==1.3.0->tensorflow-quantum==0.7.3) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib~=3.0->cirq-core==1.3.0->tensorflow-quantum==0.7.3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib~=3.0->cirq-core==1.3.0->tensorflow-quantum==0.7.3) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib~=3.0->cirq-core==1.3.0->tensorflow-quantum==0.7.3) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib~=3.0->cirq-core==1.3.0->tensorflow-quantum==0.7.3) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib~=3.0->cirq-core==1.3.0->tensorflow-quantum==0.7.3) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib~=3.0->cirq-core==1.3.0->tensorflow-quantum==0.7.3) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib~=3.0->cirq-core==1.3.0->tensorflow-quantum==0.7.3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->cirq-core==1.3.0->tensorflow-quantum==0.7.3) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->cirq-core==1.3.0->tensorflow-quantum==0.7.3) (2024.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core>=1.14.0->google-api-core[grpc]>=1.14.0->cirq-google==1.3.0->tensorflow-quantum==0.7.3) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core>=1.14.0->google-api-core[grpc]>=1.14.0->cirq-google==1.3.0->tensorflow-quantum==0.7.3) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core>=1.14.0->google-api-core[grpc]>=1.14.0->cirq-google==1.3.0->tensorflow-quantum==0.7.3) (4.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib~=3.0->cirq-core==1.3.0->tensorflow-quantum==0.7.3) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core>=1.14.0->google-api-core[grpc]>=1.14.0->cirq-google==1.3.0->tensorflow-quantum==0.7.3) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core>=1.14.0->google-api-core[grpc]>=1.14.0->cirq-google==1.3.0->tensorflow-quantum==0.7.3) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core>=1.14.0->google-api-core[grpc]>=1.14.0->cirq-google==1.3.0->tensorflow-quantum==0.7.3) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core>=1.14.0->google-api-core[grpc]>=1.14.0->cirq-google==1.3.0->tensorflow-quantum==0.7.3) (2024.12.14)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core>=1.14.0->google-api-core[grpc]>=1.14.0->cirq-google==1.3.0->tensorflow-quantum==0.7.3) (0.6.1)
# Downloading tensorflow_quantum-0.7.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 71.9 MB/s eta 0:00:00
# Downloading cirq_core-1.3.0-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 51.1 MB/s eta 0:00:00
# Downloading cirq_google-1.3.0-py3-none-any.whl (598 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 598.8/598.8 kB 28.5 MB/s eta 0:00:00
# Downloading sympy-1.12-py3-none-any.whl (5.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 93.0 MB/s eta 0:00:00
# Downloading duet-0.2.9-py3-none-any.whl (29 kB)
# Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Installing collected packages: sortedcontainers, sympy, duet, cirq-core, cirq-google, tensorflow-quantum
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.13.1
#     Uninstalling sympy-1.13.1:
#       Successfully uninstalled sympy-1.13.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torch 2.5.1+cu121 requires sympy==1.13.1; python_version >= "3.9", but you have sympy 1.12 which is incompatible.
# Successfully installed cirq-core-1.3.0 cirq-google-1.3.0 duet-0.2.9 sortedcontainers-2.4.0 sympy-1.12 tensorflow-quantum-0.7.3

# %%
import tensorflow as tf
import tensorflow_quantum as tfq
import cirq
import numpy as np
import sympy
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.model_selection import train_test_split

# Load the Fashion MNIST dataset
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()

# Filter dataset for three classes
selected_classes = [0, 1, 2]  # Modify to include three classes: e.g., 0 = T-shirt/top, 1 = Trouser, 2 = Pullover
train_filter = np.isin(y_train, selected_classes)
test_filter = np.isin(y_test, selected_classes)

x_train, y_train = x_train[train_filter], y_train[train_filter]
x_test, y_test = x_test[test_filter], y_test[test_filter]

# Preprocess the dataset: normalize and downscale
x_train = x_train / 255.0  # Normalize
x_test = x_test / 255.0

class_limit = 500
x_train_limited, y_train_limited = [], []

for cls in selected_classes:
    cls_indices = np.where(y_train == cls)[0][:class_limit]
    x_train_limited.append(x_train[cls_indices])
    y_train_limited.append(y_train[cls_indices])

# Concatenate arrays
x_train_limited = np.concatenate(x_train_limited)
y_train_limited = np.concatenate(y_train_limited)

# Assign back to training set
x_train, y_train = x_train_limited, y_train_limited

# Display shapes of processed datasets
print("Training set shape:", x_train.shape)  # Output: (number_of_samples, 28, 28)
print("Training labels shape:", y_train.shape)  # Output: (number_of_samples,)
print("Test set shape:", x_test.shape)  # Output: (number_of_test_samples, 28, 28)
print("Test labels shape:", y_test.shape)  # Output: (number_of_test_samples,)

# No need to convert labels for binary classification; retain original class labels for multi-class classification

# Further reduce dimensions for quantum efficiency (4x4 grid)
def preprocess_images(images, size=4):
    images = tf.image.resize(images[..., tf.newaxis], (size, size)).numpy()
    return images.reshape(-1, size**2)

x_train = preprocess_images(x_train)
x_test = preprocess_images(x_test)


# Define the quantum circuit
def create_quantum_circuit(qubits, params,layers):
    circuit = cirq.Circuit()
    for layer_num in range(layers):
      for i, qubit in enumerate(qubits):
          circuit.append(cirq.rz(params[i + layer_num] )(qubit))
          circuit.append(cirq.ry(params[i + len(qubits) + layer_num ] )(qubit))
          circuit.append(cirq.rz(params[i + 2*len(qubits) + 3*len(qubits)  + layer_num ])(qubit))
      for i in range(len(qubits) - 1):
          circuit.append(cirq.CZ(qubits[i], qubits[i + 1]))
    return circuit

# Create qubits and symbolic parameters
n_qubits = 16
layers = 3
qubits = [cirq.GridQubit(i, 0) for i in range(n_qubits)]
params = sympy.symbols(f'theta_0:{3*n_qubits*layers }')

# Generate a quantum circuit
example_circuit = create_quantum_circuit(qubits, params,layers)



# Convert circuits to TensorFlow Quantum Tensors



# Convert circuits to TensorFlow Quantum Tensors
def create_quantum_data(images):
    circuits = []
    for image in images:
        circuit = cirq.Circuit()
        for i, pixel in enumerate(image):
            circuit.append(cirq.rx(np.pi * pixel)(qubits[i % n_qubits]))
        circuits.append(circuit)
    return tfq.convert_to_tensor(circuits)

x_train_circuits = create_quantum_data(x_train)
x_test_circuits = create_quantum_data(x_test)


# Define the learning rate schedule
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=0.01, decay_steps=100, decay_rate=0.9
)

# Callbacks
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', patience=5, restore_best_weights=True
)

reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss', factor=0.2, patience=5, min_lr=0.0001
)

# Define the hybrid quantum-classical model using Functional API
def create_model():
    # Input layer
    quantum_input = tf.keras.Input(shape=(), dtype=tf.string, name='quantum_input')

    # Quantum layer
    quantum_layer = tfq.layers.PQC(example_circuit, [cirq.Z(q) for q in qubits])(quantum_input)

    # Dense layer with softmax for multi-class classification
    output = tf.keras.layers.Dense(len(selected_classes), activation="softmax")(quantum_layer)

    # Define the model
    model = tf.keras.Model(inputs=quantum_input, outputs=output, name='Quantum_Classifier')
    return model




model_checkpoint = tf.keras.callbacks.ModelCheckpoint(
    "best_model_f_mnist_c3_500.h5", monitor="val_loss", save_best_only=True, save_weights_only=True, verbose=1
)

# Create and compile the model
model = create_model()
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=lr_schedule),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)



# Train the model
history = model.fit(
    x_train_circuits, y_train,
    epochs=50,
    batch_size=128,
    validation_split=0.2,
    callbacks=[ model_checkpoint, reduce_lr]
)

# Load the best model weights
# Changed filename to match the one specified in ModelCheckpoint callback
model.load_weights("best_model_f_mnist_c3_500.h5")

# Evaluate the model
loss, accuracy = model.evaluate(x_test_circuits, y_test)
print(f"Test accuracy: {accuracy:.2f}")

# Plot accuracy and loss
def plot_history(history):
    plt.figure(figsize=(12, 5))

    # Plot accuracy
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title('Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    # Plot loss
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.tight_layout()
    plt.show()

plot_history(history)

# Confusion matrix
y_pred = np.argmax(model.predict(x_test_circuits), axis=1)
cm = confusion_matrix(y_test, y_pred, labels=range(len(selected_classes)))
ConfusionMatrixDisplay(cm, display_labels=selected_classes).plot(cmap='Blues')
plt.title('Confusion Matrix')
plt.show()



# Calculate precision, recall, and F1-score
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')

print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1 Score: {f1:.2f}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-c847171c43ee> in <cell line: 0>()
# ----> 1 import tensorflow as tf
#       2 import tensorflow_quantum as tfq
#       3 import cirq
#       4 import numpy as np
#       5 import sympy
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/__init__.py in <module>
#     483     importlib.import_module("tf_keras.src.optimizers")
#     484   else:
# --> 485     importlib.import_module("keras.src.optimizers")
#     486 except (ImportError, AttributeError):
#     487   pass
#
# /usr/lib/python3.11/importlib/__init__.py in import_module(name, package)
#     124                 break
#     125             level += 1
# --> 126     return _bootstrap._gcd_import(name[level:], package, level)
#     127
#     128
#
# /usr/local/lib/python3.11/dist-packages/keras/__init__.py in <module>
#       1 """AUTOGENERATED. DO NOT EDIT."""
#       2
# ----> 3 from keras import __internal__
#       4 from keras import activations
#       5 from keras import applications
#
# /usr/local/lib/python3.11/dist-packages/keras/__internal__/__init__.py in <module>
#       1 """AUTOGENERATED. DO NOT EDIT."""
#       2
# ----> 3 from keras.__internal__ import backend
#       4 from keras.__internal__ import layers
#       5 from keras.__internal__ import losses
#
# /usr/local/lib/python3.11/dist-packages/keras/__internal__/backend/__init__.py in <module>
#       1 """AUTOGENERATED. DO NOT EDIT."""
#       2
# ----> 3 from keras.src.backend import _initialize_variables as initialize_variables
#       4 from keras.src.backend import track_variable
#
# /usr/local/lib/python3.11/dist-packages/keras/src/__init__.py in <module>
#      19 """
#      20
# ---> 21 from keras.src import applications
#      22 from keras.src import distribute
#      23 from keras.src import models
#
# /usr/local/lib/python3.11/dist-packages/keras/src/applications/__init__.py in <module>
#      16
#      17
# ---> 18 from keras.src.applications.convnext import ConvNeXtBase
#      19 from keras.src.applications.convnext import ConvNeXtLarge
#      20 from keras.src.applications.convnext import ConvNeXtSmall
#
# /usr/local/lib/python3.11/dist-packages/keras/src/applications/convnext.py in <module>
#      28 from keras.src import backend
#      29 from keras.src import initializers
# ---> 30 from keras.src import layers
#      31 from keras.src import utils
#      32 from keras.src.applications import imagenet_utils
#
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/__init__.py in <module>
#      19
#      20 from keras.src.engine.base_layer import Layer
# ---> 21 from keras.src.engine.base_preprocessing_layer import PreprocessingLayer
#      22
#      23 # Generic layers.
#
# /usr/local/lib/python3.11/dist-packages/keras/src/engine/base_preprocessing_layer.py in <module>
#      19 import tensorflow.compat.v2 as tf
#      20
# ---> 21 from keras.src.engine import data_adapter
#      22 from keras.src.engine.base_layer import Layer
#      23 from keras.src.utils import version_utils
#
# /usr/local/lib/python3.11/dist-packages/keras/src/engine/data_adapter.py in <module>
#      49
#      50 try:
# ---> 51     import pandas as pd
#      52 except ImportError:
#      53     pd = None
#
# /usr/local/lib/python3.11/dist-packages/pandas/__init__.py in <module>
#      47 import pandas.core.config_init  # pyright: ignore[reportUnusedImport] # noqa: F401
#      48
# ---> 49 from pandas.core.api import (
#      50     # dtype
#      51     ArrowDtype,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/api.py in <module>
#      45 from pandas.core.construction import array
#      46 from pandas.core.flags import Flags
# ---> 47 from pandas.core.groupby import (
#      48     Grouper,
#      49     NamedAgg,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/groupby/__init__.py in <module>
# ----> 1 from pandas.core.groupby.generic import (
#       2     DataFrameGroupBy,
#       3     NamedAgg,
#       4     SeriesGroupBy,
#       5 )
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/groupby/generic.py in <module>
#      66 )
#      67 import pandas.core.common as com
# ---> 68 from pandas.core.frame import DataFrame
#      69 from pandas.core.groupby import (
#      70     base,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in <module>
#     147     sanitize_masked_array,
#     148 )
# --> 149 from pandas.core.generic import (
#     150     NDFrame,
#     151     make_doc,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in <module>
#     150 )
#     151
# --> 152 from pandas.core import (
#     153     algorithms as algos,
#     154     arraylike,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexing.py in <module>
#      77     length_of_indexer,
#      78 )
# ---> 79 from pandas.core.indexes.api import (
#      80     Index,
#      81     MultiIndex,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/api.py in <module>
#      18
#      19 from pandas.core.algorithms import safe_sort
# ---> 20 from pandas.core.indexes.base import (
#      21     Index,
#      22     _new_Index,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in <module>
#      27 )
#      28
# ---> 29 from pandas._libs import (
#      30     NaT,
#      31     algos as libalgos,
#
# /usr/lib/python3.11/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /usr/lib/python3.11/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# /usr/lib/python3.11/importlib/_bootstrap.py in _find_spec(name, path, target)
#
# /usr/lib/python3.11/importlib/_bootstrap.py in __exit__(self, exc_type, exc_value, exc_traceback)
#
# KeyboardInterrupt:

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score, confusion_matrix, ConfusionMatrixDisplay


# Calculate precision, recall, and F1-score
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')

print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1 Score: {f1:.2f}")
# Out:
# Precision: 0.75
# Recall: 0.71
# F1 Score: 0.71

# %%
import tensorflow as tf
import tensorflow_quantum as tfq
import cirq
import numpy as np
import sympy
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.model_selection import train_test_split

# Load the Fashion MNIST dataset
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()

# Filter dataset for three classes
selected_classes = [0, 1, 2]  # Modify to include three classes: e.g., 0 = T-shirt/top, 1 = Trouser, 2 = Pullover
train_filter = np.isin(y_train, selected_classes)
test_filter = np.isin(y_test, selected_classes)

x_train, y_train = x_train[train_filter], y_train[train_filter]
x_test, y_test = x_test[test_filter], y_test[test_filter]

# Preprocess the dataset: normalize and downscale
x_train = x_train / 255.0  # Normalize
x_test = x_test / 255.0

class_limit = 1000
x_train_limited, y_train_limited = [], []

for cls in selected_classes:
    cls_indices = np.where(y_train == cls)[0][:class_limit]
    x_train_limited.append(x_train[cls_indices])
    y_train_limited.append(y_train[cls_indices])

# Concatenate arrays
x_train_limited = np.concatenate(x_train_limited)
y_train_limited = np.concatenate(y_train_limited)

# Assign back to training set
x_train, y_train = x_train_limited, y_train_limited

# Display shapes of processed datasets
print("Training set shape:", x_train.shape)  # Output: (number_of_samples, 28, 28)
print("Training labels shape:", y_train.shape)  # Output: (number_of_samples,)
print("Test set shape:", x_test.shape)  # Output: (number_of_test_samples, 28, 28)
print("Test labels shape:", y_test.shape)  # Output: (number_of_test_samples,)

# No need to convert labels for binary classification; retain original class labels for multi-class classification

# Further reduce dimensions for quantum efficiency (4x4 grid)
def preprocess_images(images, size=4):
    images = tf.image.resize(images[..., tf.newaxis], (size, size)).numpy()
    return images.reshape(-1, size**2)

x_train = preprocess_images(x_train)
x_test = preprocess_images(x_test)


# Define the quantum circuit
def create_quantum_circuit(qubits, params,layers):
    circuit = cirq.Circuit()
    for layer_num in range(layers):
      for i, qubit in enumerate(qubits):
          circuit.append(cirq.rz(params[i + layer_num] )(qubit))
          circuit.append(cirq.ry(params[i + len(qubits) + layer_num ] )(qubit))
          circuit.append(cirq.rz(params[i + 2*len(qubits) + 3*len(qubits)  + layer_num ])(qubit))
      for i in range(len(qubits) - 1):
          circuit.append(cirq.CZ(qubits[i], qubits[i + 1]))
    return circuit

# Create qubits and symbolic parameters
n_qubits = 16
layers = 3
qubits = [cirq.GridQubit(i, 0) for i in range(n_qubits)]
params = sympy.symbols(f'theta_0:{3*n_qubits*layers }')

# Generate a quantum circuit
example_circuit = create_quantum_circuit(qubits, params,layers)



# Convert circuits to TensorFlow Quantum Tensors



# Convert circuits to TensorFlow Quantum Tensors
def create_quantum_data(images):
    circuits = []
    for image in images:
        circuit = cirq.Circuit()
        for i, pixel in enumerate(image):
            circuit.append(cirq.rx(np.pi * pixel)(qubits[i % n_qubits]))
        circuits.append(circuit)
    return tfq.convert_to_tensor(circuits)

x_train_circuits = create_quantum_data(x_train)
x_test_circuits = create_quantum_data(x_test)


# Define the learning rate schedule
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=0.01, decay_steps=100, decay_rate=0.9
)

# Callbacks
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', patience=5, restore_best_weights=True
)

reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss', factor=0.2, patience=5, min_lr=0.0001
)

# Define the hybrid quantum-classical model using Functional API
def create_model():
    # Input layer
    quantum_input = tf.keras.Input(shape=(), dtype=tf.string, name='quantum_input')

    # Quantum layer
    quantum_layer = tfq.layers.PQC(example_circuit, [cirq.Z(q) for q in qubits])(quantum_input)

    # Dense layer with softmax for multi-class classification
    output = tf.keras.layers.Dense(len(selected_classes), activation="softmax")(quantum_layer)

    # Define the model
    model = tf.keras.Model(inputs=quantum_input, outputs=output, name='Quantum_Classifier')
    return model




model_checkpoint = tf.keras.callbacks.ModelCheckpoint(
    "best_model_f_mnist_c3_1000.h5", monitor="val_loss", save_best_only=True, save_weights_only=True, verbose=1
)

# Create and compile the model
model = create_model()
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=lr_schedule),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)



# Train the model
history = model.fit(
    x_train_circuits, y_train,
    epochs=50,
    batch_size=128,
    validation_split=0.2,
    callbacks=[ model_checkpoint, reduce_lr]
)

# Load the best model weights
# Changed filename to match the one specified in ModelCheckpoint callback
model.load_weights("best_model_f_mnist_c3_1000.h5")

# Evaluate the model
loss, accuracy = model.evaluate(x_test_circuits, y_test)
print(f"Test accuracy: {accuracy:.2f}")

# Plot accuracy and loss
def plot_history(history):
    plt.figure(figsize=(12, 5))

    # Plot accuracy
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title('Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    # Plot loss
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.tight_layout()
    plt.show()

plot_history(history)

# Confusion matrix
y_pred = np.argmax(model.predict(x_test_circuits), axis=1)
cm = confusion_matrix(y_test, y_pred, labels=range(len(selected_classes)))
ConfusionMatrixDisplay(cm, display_labels=selected_classes).plot(cmap='Blues')
plt.title('Confusion Matrix')
plt.show()

from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score, confusion_matrix, ConfusionMatrixDisplay

# Calculate precision, recall, and F1-score
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')

print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1 Score: {f1:.2f}")
# Out:
# Training set shape: (3000, 28, 28)
# Training labels shape: (3000,)
# Test set shape: (3000, 28, 28)
# Test labels shape: (3000,)
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/initializers/initializers.py:120: UserWarning: The initializer RandomUniform is unseeded and being called multiple times, which will return identical values each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initializer instance more than once.
#   warnings.warn(
# 19/19 [==============================] - ETA: 0s - loss: 0.9805 - accuracy: 0.4871
# Epoch 1: val_loss improved from inf to 1.68943, saving model to best_model_f_mnist_c3_1000.h5
# 19/19 [==============================] - 234s 12s/step - loss: 0.9805 - accuracy: 0.4871 - val_loss: 1.6894 - val_accuracy: 0.0350 - lr: 0.0098
# Epoch 2/50
# 19/19 [==============================] - ETA: 0s - loss: 0.8638 - accuracy: 0.6288
# Epoch 2: val_loss improved from 1.68943 to 1.37142, saving model to best_model_f_mnist_c3_1000.h5
# 19/19 [==============================] - 230s 12s/step - loss: 0.8638 - accuracy: 0.6288 - val_loss: 1.3714 - val_accuracy: 0.3300 - lr: 0.0096
# Epoch 3/50
# 19/19 [==============================] - ETA: 0s - loss: 0.7705 - accuracy: 0.7208
# Epoch 3: val_loss improved from 1.37142 to 1.27033, saving model to best_model_f_mnist_c3_1000.h5
# 19/19 [==============================] - 229s 12s/step - loss: 0.7705 - accuracy: 0.7208 - val_loss: 1.2703 - val_accuracy: 0.4450 - lr: 0.0094
# Epoch 4/50
# 19/19 [==============================] - ETA: 0s - loss: 0.6944 - accuracy: 0.7296
# Epoch 4: val_loss improved from 1.27033 to 1.21545, saving model to best_model_f_mnist_c3_1000.h5
# 19/19 [==============================] - 234s 12s/step - loss: 0.6944 - accuracy: 0.7296 - val_loss: 1.2155 - val_accuracy: 0.4583 - lr: 0.0092
# Epoch 5/50
# 19/19 [==============================] - ETA: 0s - loss: 0.6538 - accuracy: 0.7358
# Epoch 5: val_loss improved from 1.21545 to 1.20209, saving model to best_model_f_mnist_c3_1000.h5
# 19/19 [==============================] - 229s 12s/step - loss: 0.6538 - accuracy: 0.7358 - val_loss: 1.2021 - val_accuracy: 0.4800 - lr: 0.0091
# Epoch 6/50
# 19/19 [==============================] - ETA: 0s - loss: 0.6337 - accuracy: 0.7367
# Epoch 6: val_loss improved from 1.20209 to 1.15748, saving model to best_model_f_mnist_c3_1000.h5
# 19/19 [==============================] - 228s 12s/step - loss: 0.6337 - accuracy: 0.7367 - val_loss: 1.1575 - val_accuracy: 0.4983 - lr: 0.0089
# Epoch 7/50
# 19/19 [==============================] - ETA: 0s - loss: 0.6190 - accuracy: 0.7479
# Epoch 7: val_loss improved from 1.15748 to 1.12571, saving model to best_model_f_mnist_c3_1000.h5
# 19/19 [==============================] - 228s 12s/step - loss: 0.6190 - accuracy: 0.7479 - val_loss: 1.1257 - val_accuracy: 0.5067 - lr: 0.0087
# Epoch 8/50
# 19/19 [==============================] - ETA: 0s - loss: 0.6061 - accuracy: 0.7542
# Epoch 8: val_loss improved from 1.12571 to 1.09434, saving model to best_model_f_mnist_c3_1000.h5
# 19/19 [==============================] - 229s 12s/step - loss: 0.6061 - accuracy: 0.7542 - val_loss: 1.0943 - val_accuracy: 0.5133 - lr: 0.0085
# Epoch 9/50
# 19/19 [==============================] - ETA: 0s - loss: 0.5964 - accuracy: 0.7550
# Epoch 9: val_loss improved from 1.09434 to 1.04814, saving model to best_model_f_mnist_c3_1000.h5
# 19/19 [==============================] - 231s 12s/step - loss: 0.5964 - accuracy: 0.7550 - val_loss: 1.0481 - val_accuracy: 0.5117 - lr: 0.0084
# Epoch 10/50
# 19/19 [==============================] - ETA: 0s - loss: 0.5902 - accuracy: 0.7546
# Epoch 10: val_loss did not improve from 1.04814
# 19/19 [==============================] - 230s 12s/step - loss: 0.5902 - accuracy: 0.7546 - val_loss: 1.1381 - val_accuracy: 0.5117 - lr: 0.0082
# Epoch 11/50
# 19/19 [==============================] - ETA: 0s - loss: 0.5828 - accuracy: 0.7563
# Epoch 11: val_loss improved from 1.04814 to 0.99771, saving model to best_model_f_mnist_c3_1000.h5
# 19/19 [==============================] - 228s 12s/step - loss: 0.5828 - accuracy: 0.7563 - val_loss: 0.9977 - val_accuracy: 0.5200 - lr: 0.0080
# Epoch 12/50
# 19/19 [==============================] - ETA: 0s - loss: 0.5756 - accuracy: 0.7550
# Epoch 12: val_loss did not improve from 0.99771
# 19/19 [==============================] - 231s 12s/step - loss: 0.5756 - accuracy: 0.7550 - val_loss: 1.1086 - val_accuracy: 0.5117 - lr: 0.0079
# Epoch 13/50
# 19/19 [==============================] - ETA: 0s - loss: 0.5714 - accuracy: 0.7592
# Epoch 13: val_loss did not improve from 0.99771
# 19/19 [==============================] - 230s 12s/step - loss: 0.5714 - accuracy: 0.7592 - val_loss: 1.0287 - val_accuracy: 0.5233 - lr: 0.0077
# Epoch 14/50
# 19/19 [==============================] - ETA: 0s - loss: 0.5668 - accuracy: 0.7613
# Epoch 14: val_loss did not improve from 0.99771
# 19/19 [==============================] - 231s 12s/step - loss: 0.5668 - accuracy: 0.7613 - val_loss: 1.0601 - val_accuracy: 0.5183 - lr: 0.0076
# Epoch 15/50
# 19/19 [==============================] - ETA: 0s - loss: 0.5635 - accuracy: 0.7596
# Epoch 15: val_loss did not improve from 0.99771
# 19/19 [==============================] - 230s 12s/step - loss: 0.5635 - accuracy: 0.7596 - val_loss: 1.0085 - val_accuracy: 0.5300 - lr: 0.0074
# Epoch 16/50
# 19/19 [==============================] - ETA: 0s - loss: 0.5600 - accuracy: 0.7567
# Epoch 16: val_loss did not improve from 0.99771
# 19/19 [==============================] - 231s 12s/step - loss: 0.5600 - accuracy: 0.7567 - val_loss: 1.1070 - val_accuracy: 0.5200 - lr: 0.0073
# Epoch 17/50
# 19/19 [==============================] - ETA: 0s - loss: 0.5567 - accuracy: 0.7642
# Epoch 17: val_loss did not improve from 0.99771
# 19/19 [==============================] - 230s 12s/step - loss: 0.5567 - accuracy: 0.7642 - val_loss: 1.0255 - val_accuracy: 0.5300 - lr: 0.0071
# Epoch 18/50
# 19/19 [==============================] - ETA: 0s - loss: 0.5554 - accuracy: 0.7621
# Epoch 18: val_loss did not improve from 0.99771
# 19/19 [==============================] - 228s 12s/step - loss: 0.5554 - accuracy: 0.7621 - val_loss: 1.0875 - val_accuracy: 0.5217 - lr: 0.0070
# Epoch 19/50
# 19/19 [==============================] - ETA: 0s - loss: 0.5521 - accuracy: 0.7667
# Epoch 19: val_loss did not improve from 0.99771
# 19/19 [==============================] - 230s 12s/step - loss: 0.5521 - accuracy: 0.7667 - val_loss: 1.0083 - val_accuracy: 0.5350 - lr: 0.0068
# Epoch 20/50
# 19/19 [==============================] - ETA: 0s - loss: 0.5513 - accuracy: 0.7654
# Epoch 20: val_loss improved from 0.99771 to 0.98535, saving model to best_model_f_mnist_c3_1000.h5
# 19/19 [==============================] - 228s 12s/step - loss: 0.5513 - accuracy: 0.7654 - val_loss: 0.9854 - val_accuracy: 0.5383 - lr: 0.0067
# Epoch 21/50
# 19/19 [==============================] - ETA: 0s - loss: 0.5460 - accuracy: 0.7646
# Epoch 21: val_loss did not improve from 0.98535
# 19/19 [==============================] - 229s 12s/step - loss: 0.5460 - accuracy: 0.7646 - val_loss: 1.0173 - val_accuracy: 0.5450 - lr: 0.0066
# Epoch 22/50
# 19/19 [==============================] - ETA: 0s - loss: 0.5443 - accuracy: 0.7675
# Epoch 22: val_loss improved from 0.98535 to 0.97945, saving model to best_model_f_mnist_c3_1000.h5
# 19/19 [==============================] - 228s 12s/step - loss: 0.5443 - accuracy: 0.7675 - val_loss: 0.9795 - val_accuracy: 0.5517 - lr: 0.0064
# Epoch 23/50
# 19/19 [==============================] - ETA: 0s - loss: 0.5423 - accuracy: 0.7704
# Epoch 23: val_loss did not improve from 0.97945
# 19/19 [==============================] - 230s 12s/step - loss: 0.5423 - accuracy: 0.7704 - val_loss: 1.0378 - val_accuracy: 0.5350 - lr: 0.0063
# Epoch 24/50
# 19/19 [==============================] - ETA: 0s - loss: 0.5433 - accuracy: 0.7704
# Epoch 24: val_loss did not improve from 0.97945
# 19/19 [==============================] - 229s 12s/step - loss: 0.5433 - accuracy: 0.7704 - val_loss: 0.9951 - val_accuracy: 0.5383 - lr: 0.0062
# Epoch 25/50
# 19/19 [==============================] - ETA: 0s - loss: 0.5408 - accuracy: 0.7717
# Epoch 25: val_loss did not improve from 0.97945
# 19/19 [==============================] - 229s 12s/step - loss: 0.5408 - accuracy: 0.7717 - val_loss: 1.0000 - val_accuracy: 0.5517 - lr: 0.0061
# Epoch 26/50
# 19/19 [==============================] - ETA: 0s - loss: 0.5379 - accuracy: 0.7688
# Epoch 26: val_loss improved from 0.97945 to 0.96427, saving model to best_model_f_mnist_c3_1000.h5
# 19/19 [==============================] - 224s 12s/step - loss: 0.5379 - accuracy: 0.7688 - val_loss: 0.9643 - val_accuracy: 0.5483 - lr: 0.0059
# Epoch 27/50
# 19/19 [==============================] - ETA: 0s - loss: 0.5375 - accuracy: 0.7688
# Epoch 27: val_loss did not improve from 0.96427
# 19/19 [==============================] - 229s 12s/step - loss: 0.5375 - accuracy: 0.7688 - val_loss: 0.9890 - val_accuracy: 0.5417 - lr: 0.0058
# Epoch 28/50
# 19/19 [==============================] - ETA: 0s - loss: 0.5350 - accuracy: 0.7688
# Epoch 28: val_loss did not improve from 0.96427
# 19/19 [==============================] - 226s 12s/step - loss: 0.5350 - accuracy: 0.7688 - val_loss: 0.9814 - val_accuracy: 0.5500 - lr: 0.0057
# Epoch 29/50
# 19/19 [==============================] - ETA: 0s - loss: 0.5358 - accuracy: 0.7700
# Epoch 29: val_loss did not improve from 0.96427
# 19/19 [==============================] - 229s 12s/step - loss: 0.5358 - accuracy: 0.7700 - val_loss: 1.0238 - val_accuracy: 0.5467 - lr: 0.0056
# Epoch 30/50
# 19/19 [==============================] - ETA: 0s - loss: 0.5336 - accuracy: 0.7717
# Epoch 30: val_loss did not improve from 0.96427
# 19/19 [==============================] - 229s 12s/step - loss: 0.5336 - accuracy: 0.7717 - val_loss: 0.9934 - val_accuracy: 0.5517 - lr: 0.0055
# Epoch 31/50
# 19/19 [==============================] - ETA: 0s - loss: 0.5355 - accuracy: 0.7688
# Epoch 31: val_loss did not improve from 0.96427
# 19/19 [==============================] - 231s 12s/step - loss: 0.5355 - accuracy: 0.7688 - val_loss: 1.0124 - val_accuracy: 0.5517 - lr: 0.0054
# Epoch 32/50
# 19/19 [==============================] - ETA: 0s - loss: 0.5333 - accuracy: 0.7742
# Epoch 32: val_loss did not improve from 0.96427
# 19/19 [==============================] - 229s 12s/step - loss: 0.5333 - accuracy: 0.7742 - val_loss: 0.9989 - val_accuracy: 0.5517 - lr: 0.0053
# Epoch 33/50
# 19/19 [==============================] - ETA: 0s - loss: 0.5337 - accuracy: 0.7733
# Epoch 33: val_loss did not improve from 0.96427
# 19/19 [==============================] - 229s 12s/step - loss: 0.5337 - accuracy: 0.7733 - val_loss: 1.0304 - val_accuracy: 0.5483 - lr: 0.0052
# Epoch 34/50
# 19/19 [==============================] - ETA: 0s - loss: 0.5330 - accuracy: 0.7708
# Epoch 34: val_loss did not improve from 0.96427
# 19/19 [==============================] - 230s 12s/step - loss: 0.5330 - accuracy: 0.7708 - val_loss: 0.9747 - val_accuracy: 0.5600 - lr: 0.0051
# Epoch 35/50
# 19/19 [==============================] - ETA: 0s - loss: 0.5327 - accuracy: 0.7763
# Epoch 35: val_loss did not improve from 0.96427
# 19/19 [==============================] - 229s 12s/step - loss: 0.5327 - accuracy: 0.7763 - val_loss: 0.9747 - val_accuracy: 0.5567 - lr: 0.0050
# Epoch 36/50
# 19/19 [==============================] - ETA: 0s - loss: 0.5309 - accuracy: 0.7746
# Epoch 36: val_loss did not improve from 0.96427
# 19/19 [==============================] - 230s 12s/step - loss: 0.5309 - accuracy: 0.7746 - val_loss: 0.9726 - val_accuracy: 0.5550 - lr: 0.0049
# Epoch 37/50
# 19/19 [==============================] - ETA: 0s - loss: 0.5276 - accuracy: 0.7758
# Epoch 37: val_loss did not improve from 0.96427
# 19/19 [==============================] - 229s 12s/step - loss: 0.5276 - accuracy: 0.7758 - val_loss: 0.9813 - val_accuracy: 0.5583 - lr: 0.0048
# Epoch 38/50
# 19/19 [==============================] - ETA: 0s - loss: 0.5272 - accuracy: 0.7758
# Epoch 38: val_loss did not improve from 0.96427
# 19/19 [==============================] - 229s 12s/step - loss: 0.5272 - accuracy: 0.7758 - val_loss: 0.9924 - val_accuracy: 0.5550 - lr: 0.0047
# Epoch 39/50
# 19/19 [==============================] - ETA: 0s - loss: 0.5268 - accuracy: 0.7767
# Epoch 39: val_loss improved from 0.96427 to 0.94356, saving model to best_model_f_mnist_c3_1000.h5
# 19/19 [==============================] - 230s 12s/step - loss: 0.5268 - accuracy: 0.7767 - val_loss: 0.9436 - val_accuracy: 0.5617 - lr: 0.0046
# Epoch 40/50
# 19/19 [==============================] - ETA: 0s - loss: 0.5264 - accuracy: 0.7771
# Epoch 40: val_loss did not improve from 0.94356
# 19/19 [==============================] - 228s 12s/step - loss: 0.5264 - accuracy: 0.7771 - val_loss: 0.9931 - val_accuracy: 0.5533 - lr: 0.0045
# Epoch 41/50
# 19/19 [==============================] - ETA: 0s - loss: 0.5258 - accuracy: 0.7750
# Epoch 41: val_loss did not improve from 0.94356
# 19/19 [==============================] - 231s 12s/step - loss: 0.5258 - accuracy: 0.7750 - val_loss: 0.9811 - val_accuracy: 0.5550 - lr: 0.0044
# Epoch 42/50
# 19/19 [==============================] - ETA: 0s - loss: 0.5254 - accuracy: 0.7775
# Epoch 42: val_loss did not improve from 0.94356
# 19/19 [==============================] - 228s 12s/step - loss: 0.5254 - accuracy: 0.7775 - val_loss: 0.9983 - val_accuracy: 0.5583 - lr: 0.0043
# Epoch 43/50
# 19/19 [==============================] - ETA: 0s - loss: 0.5246 - accuracy: 0.7779
# Epoch 43: val_loss did not improve from 0.94356
# 19/19 [==============================] - 230s 12s/step - loss: 0.5246 - accuracy: 0.7779 - val_loss: 0.9765 - val_accuracy: 0.5567 - lr: 0.0042
# Epoch 44/50
# 19/19 [==============================] - ETA: 0s - loss: 0.5231 - accuracy: 0.7783
# Epoch 44: val_loss did not improve from 0.94356
# 19/19 [==============================] - 230s 12s/step - loss: 0.5231 - accuracy: 0.7783 - val_loss: 0.9472 - val_accuracy: 0.5633 - lr: 0.0041
# Epoch 45/50
# 19/19 [==============================] - ETA: 0s - loss: 0.5237 - accuracy: 0.7812
# Epoch 45: val_loss did not improve from 0.94356
# 19/19 [==============================] - 229s 12s/step - loss: 0.5237 - accuracy: 0.7812 - val_loss: 0.9554 - val_accuracy: 0.5617 - lr: 0.0041
# Epoch 46/50
# 19/19 [==============================] - ETA: 0s - loss: 0.5244 - accuracy: 0.7812
# Epoch 46: val_loss did not improve from 0.94356
# 19/19 [==============================] - 231s 12s/step - loss: 0.5244 - accuracy: 0.7812 - val_loss: 0.9990 - val_accuracy: 0.5583 - lr: 0.0040
# Epoch 47/50
# 19/19 [==============================] - ETA: 0s - loss: 0.5236 - accuracy: 0.7771
# Epoch 47: val_loss did not improve from 0.94356
# 19/19 [==============================] - 229s 12s/step - loss: 0.5236 - accuracy: 0.7771 - val_loss: 0.9704 - val_accuracy: 0.5600 - lr: 0.0039
# Epoch 48/50
# 19/19 [==============================] - ETA: 0s - loss: 0.5209 - accuracy: 0.7917
# Epoch 48: val_loss did not improve from 0.94356
# 19/19 [==============================] - 231s 12s/step - loss: 0.5209 - accuracy: 0.7917 - val_loss: 0.9795 - val_accuracy: 0.5600 - lr: 0.0038
# Epoch 49/50
# 19/19 [==============================] - ETA: 0s - loss: 0.5228 - accuracy: 0.7767
# Epoch 49: val_loss did not improve from 0.94356
# 19/19 [==============================] - 230s 12s/step - loss: 0.5228 - accuracy: 0.7767 - val_loss: 0.9619 - val_accuracy: 0.5717 - lr: 0.0038
# Epoch 50/50
# 19/19 [==============================] - ETA: 0s - loss: 0.5232 - accuracy: 0.7796
# Epoch 50: val_loss did not improve from 0.94356
# 19/19 [==============================] - 230s 12s/step - loss: 0.5232 - accuracy: 0.7796 - val_loss: 0.9677 - val_accuracy: 0.5617 - lr: 0.0037
# 94/94 [==============================] - 40s 427ms/step - loss: 0.6479 - accuracy: 0.7140
# Test accuracy: 0.71
# 94/94 [==============================] - 42s 447ms/step
# Precision: 0.75
# Recall: 0.71
# F1 Score: 0.71

# %%
import tensorflow as tf
import tensorflow_quantum as tfq
import cirq
import numpy as np
import sympy
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.model_selection import train_test_split

# Load the Fashion MNIST dataset
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()

# Filter dataset for three classes
selected_classes = [0, 1, 2]  # Modify to include three classes: e.g., 0 = T-shirt/top, 1 = Trouser, 2 = Pullover
train_filter = np.isin(y_train, selected_classes)
test_filter = np.isin(y_test, selected_classes)

x_train, y_train = x_train[train_filter], y_train[train_filter]
x_test, y_test = x_test[test_filter], y_test[test_filter]

# Preprocess the dataset: normalize and downscale
x_train = x_train / 255.0  # Normalize
x_test = x_test / 255.0

class_limit = 1000
x_train_limited, y_train_limited = [], []

for cls in selected_classes:
    cls_indices = np.where(y_train == cls)[0][:class_limit]
    x_train_limited.append(x_train[cls_indices])
    y_train_limited.append(y_train[cls_indices])

# Concatenate arrays
x_train_limited = np.concatenate(x_train_limited)
y_train_limited = np.concatenate(y_train_limited)

# Assign back to training set
x_train, y_train = x_train_limited, y_train_limited


test_limit = 1000
n=0
x_test = x_test[n*1000:n*1000+test_limit]
y_test = y_test[n*1000:n*1000+test_limit]


# Display shapes of processed datasets
print("Training set shape:", x_train.shape)  # Output: (number_of_samples, 28, 28)
print("Training labels shape:", y_train.shape)  # Output: (number_of_samples,)
print("Test set shape:", x_test.shape)  # Output: (number_of_test_samples, 28, 28)
print("Test labels shape:", y_test.shape)  # Output: (number_of_test_samples,)

# No need to convert labels for binary classification; retain original class labels for multi-class classification

# Further reduce dimensions for quantum efficiency (4x4 grid)
def preprocess_images(images, size=4):
    images = tf.image.resize(images[..., tf.newaxis], (size, size)).numpy()
    return images.reshape(-1, size**2)

x_train = preprocess_images(x_train)
x_test = preprocess_images(x_test)


# Define the quantum circuit with unique parameters for each gate
def create_quantum_circuit(qubits, params, layers):
    circuit = cirq.Circuit()
    param_index = 0  # Initialize parameter index

    for layer_num in range(layers):
        for i, qubit in enumerate(qubits):
            # Each gate gets a unique parameter
            circuit.append(cirq.rz(params[param_index])(qubit))
            param_index += 1
            circuit.append(cirq.ry(params[param_index])(qubit))
            param_index += 1
            circuit.append(cirq.rz(params[param_index])(qubit))
            param_index += 1

        # Add entanglement layer with CZ gates
        for i in range(len(qubits) - 1):
            circuit.append(cirq.CZ(qubits[i], qubits[i + 1]))

    return circuit


# Create qubits and symbolic parameters
n_qubits = 16
layers = 3
qubits = [cirq.GridQubit(i, 0) for i in range(n_qubits)]
params = sympy.symbols(f'theta_0:{3*n_qubits*layers }')

# Generate a quantum circuit
example_circuit = create_quantum_circuit(qubits, params,layers)



# Convert circuits to TensorFlow Quantum Tensors



# Convert circuits to TensorFlow Quantum Tensors
def create_quantum_data(images):
    circuits = []
    for image in images:
        circuit = cirq.Circuit()
        for i, pixel in enumerate(image):
            circuit.append(cirq.rx(np.pi * pixel)(qubits[i % n_qubits]))
        circuits.append(circuit)
    return tfq.convert_to_tensor(circuits)

x_train_circuits = create_quantum_data(x_train)
x_test_circuits = create_quantum_data(x_test)


# Define the learning rate schedule
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=0.01, decay_steps=100, decay_rate=0.9
)

# Callbacks
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', patience=5, restore_best_weights=True
)

reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss', factor=0.2, patience=5, min_lr=0.0001
)

# Define the hybrid quantum-classical model using Functional API
def create_model():
    # Input layer
    quantum_input = tf.keras.Input(shape=(), dtype=tf.string, name='quantum_input')

    # Quantum layer
    quantum_layer = tfq.layers.PQC(example_circuit, [cirq.Z(q) for q in qubits])(quantum_input)

    # Dense layer with softmax for multi-class classification
    output = tf.keras.layers.Dense(len(selected_classes), activation="softmax")(quantum_layer)

    # Define the model
    model = tf.keras.Model(inputs=quantum_input, outputs=output, name='Quantum_Classifier')
    return model

# Create and compile the model
model = create_model()
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=lr_schedule),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)
# Out:
# Training set shape: (3000, 28, 28)
# Training labels shape: (3000,)
# Test set shape: (1000, 28, 28)
# Test labels shape: (1000,)

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score, confusion_matrix, ConfusionMatrixDisplay
# Load the saved weights
model.load_weights("/content/best_model_f_mnist_c3_500.h5")
print("Weights loaded successfully.")

# Evaluate the model on the test dataset
loss, accuracy = model.evaluate(x_test_circuits, y_test, verbose=0)
print(f"Test Loss: {loss:.4f}")
print(f"Test Accuracy: {accuracy:.4f}")

# Generate predictions
y_pred = np.argmax(model.predict(x_test_circuits), axis=1)

# Calculate precision, recall, and F1-score
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')

# Print metrics rounded to two decimals
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")

# Confusion matrix
cm = confusion_matrix(y_test, y_pred, labels=range(len(selected_classes)))
ConfusionMatrixDisplay(cm, display_labels=selected_classes).plot(cmap='Blues')
plt.title('Confusion Matrix')
plt.show()
# Out:
# Weights loaded successfully.
# Test Loss: 0.5918
# Test Accuracy: 0.7510
# 32/32 [==============================] - 14s 426ms/step
# Precision: 0.7757
# Recall: 0.7510
# F1 Score: 0.7522

# %%
# Load the saved weights
model.load_weights("/content/best_model_f_mnist_c3_1000.h5")
print("Weights loaded successfully.")

# Evaluate the model on the test dataset
loss, accuracy = model.evaluate(x_test_circuits, y_test, verbose=0)
print(f"Test Loss: {loss:.4f}")
print(f"Test Accuracy: {accuracy:.4f}")

# Generate predictions
y_pred = np.argmax(model.predict(x_test_circuits), axis=1)

# Calculate precision, recall, and F1-score
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')

# Print metrics rounded to two decimals
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")

# Confusion matrix
cm = confusion_matrix(y_test, y_pred, labels=range(len(selected_classes)))
ConfusionMatrixDisplay(cm, display_labels=selected_classes).plot(cmap='Blues')
plt.title('Confusion Matrix')
plt.show()
# Out:
# Weights loaded successfully.
# Test Loss: 0.6250
# Test Accuracy: 0.7400
# 32/32 [==============================] - 14s 421ms/step
# Precision: 0.7776
# Recall: 0.7400
# F1 Score: 0.7404

# %%
import tensorflow as tf
import tensorflow_quantum as tfq
import cirq
import numpy as np
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# Load the model
model.load_weights('/content/best_model_f_mnist_c3_500.h5')  # Replace with the correct path

# Extract features from the quantum layer
quantum_layer_model = tf.keras.Model(inputs=model.input, outputs=model.get_layer(index=1).output)
quantum_features = quantum_layer_model.predict(x_test_circuits)

# Perform t-SNE dimensionality reduction
tsne = TSNE(n_components=2, perplexity=30, random_state=42)
features_2d = tsne.fit_transform(quantum_features)

plt.figure(figsize=(8, 6))
for label in np.unique(y_test):
    indices = np.where(y_test == label)
    plt.scatter(features_2d[indices, 0], features_2d[indices, 1], label=f'Class {label}', alpha=0.7)
plt.legend()
plt.title('t-SNE Visualization of Quantum Layer Output Features')
plt.xlabel('t-SNE Component 1')
plt.ylabel('t-SNE Component 2')
plt.show()
# Out:
# 32/32 [==============================] - 15s 454ms/step

# %%
import tensorflow as tf
import tensorflow_quantum as tfq
import cirq
import numpy as np
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# Load the model
model.load_weights('/content/best_model_f_mnist_c3_1000.h5')  # Replace with the correct path

# Extract features from the quantum layer
quantum_layer_model = tf.keras.Model(inputs=model.input, outputs=model.get_layer(index=1).output)
quantum_features = quantum_layer_model.predict(x_test_circuits)

# Perform t-SNE dimensionality reduction
tsne = TSNE(n_components=2, perplexity=30, random_state=42)
features_2d = tsne.fit_transform(quantum_features)

plt.figure(figsize=(8, 6))
for label in np.unique(y_test):
    indices = np.where(y_test == label)
    plt.scatter(features_2d[indices, 0], features_2d[indices, 1], label=f'Class {label}', alpha=0.7)
plt.legend()
plt.title('t-SNE Visualization of Quantum Layer Output Features')
plt.xlabel('t-SNE Component 1')
plt.ylabel('t-SNE Component 2')
plt.show()
# Out:
# 32/32 [==============================] - 14s 451ms/step
