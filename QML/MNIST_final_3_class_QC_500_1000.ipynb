# %%
# !pip install tensorflow==2.15.0
# !pip install tensorflow-quantum==0.7.3
# Out:
# Collecting tensorflow==2.15.0
#   Downloading tensorflow-2.15.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.4 kB)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (24.12.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (3.12.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (18.1.1)
# Collecting ml-dtypes~=0.2.0 (from tensorflow==2.15.0)
#   Downloading ml_dtypes-0.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (1.26.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (4.25.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (4.12.2)
# Collecting wrapt<1.15,>=1.11.0 (from tensorflow==2.15.0)
#   Downloading wrapt-1.14.1-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (0.37.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (1.69.0)
# Collecting tensorboard<2.16,>=2.15 (from tensorflow==2.15.0)
#   Downloading tensorboard-2.15.2-py3-none-any.whl.metadata (1.7 kB)
# Collecting tensorflow-estimator<2.16,>=2.15.0 (from tensorflow==2.15.0)
#   Downloading tensorflow_estimator-2.15.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting keras<2.16,>=2.15.0 (from tensorflow==2.15.0)
#   Downloading keras-2.15.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow==2.15.0) (0.45.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (1.2.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.7)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.1.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (2024.12.14)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.0.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.2.2)
# Downloading tensorflow-2.15.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (475.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 475.3/475.3 MB 1.1 MB/s eta 0:00:00
# Downloading keras-2.15.0-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 16.8 MB/s eta 0:00:00
# Downloading ml_dtypes-0.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 34.8 MB/s eta 0:00:00
# Downloading tensorboard-2.15.2-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 42.0 MB/s eta 0:00:00
# Downloading tensorflow_estimator-2.15.0-py2.py3-none-any.whl (441 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.0/442.0 kB 20.5 MB/s eta 0:00:00
# Downloading wrapt-1.14.1-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 kB 5.9 MB/s eta 0:00:00
# Installing collected packages: wrapt, tensorflow-estimator, ml-dtypes, keras, tensorboard, tensorflow
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.17.0
#     Uninstalling wrapt-1.17.0:
#       Successfully uninstalled wrapt-1.17.0
#   Attempting uninstall: ml-dtypes
#     Found existing installation: ml-dtypes 0.4.1
#     Uninstalling ml-dtypes-0.4.1:
#       Successfully uninstalled ml-dtypes-0.4.1
#   Attempting uninstall: keras
#     Found existing installation: keras 3.5.0
#     Uninstalling keras-3.5.0:
#       Successfully uninstalled keras-3.5.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.17.1
#     Uninstalling tensorboard-2.17.1:
#       Successfully uninstalled tensorboard-2.17.1
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.17.1
#     Uninstalling tensorflow-2.17.1:
#       Successfully uninstalled tensorflow-2.17.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorstore 0.1.71 requires ml_dtypes>=0.3.1, but you have ml-dtypes 0.2.0 which is incompatible.
# tf-keras 2.17.0 requires tensorflow<2.18,>=2.17, but you have tensorflow 2.15.0 which is incompatible.
# Successfully installed keras-2.15.0 ml-dtypes-0.2.0 tensorboard-2.15.2 tensorflow-2.15.0 tensorflow-estimator-2.15.0 wrapt-1.14.1
# Collecting tensorflow-quantum==0.7.3
#   Downloading tensorflow_quantum-0.7.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.7 kB)
# Collecting cirq-core==1.3.0 (from tensorflow-quantum==0.7.3)
#   Downloading cirq_core-1.3.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting cirq-google==1.3.0 (from tensorflow-quantum==0.7.3)
#   Downloading cirq_google-1.3.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting sympy==1.12 (from tensorflow-quantum==0.7.3)
#   Downloading sympy-1.12-py3-none-any.whl.metadata (12 kB)
# Collecting duet~=0.2.8 (from cirq-core==1.3.0->tensorflow-quantum==0.7.3)
#   Downloading duet-0.2.9-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: matplotlib~=3.0 in /usr/local/lib/python3.11/dist-packages (from cirq-core==1.3.0->tensorflow-quantum==0.7.3) (3.10.0)
# Requirement already satisfied: networkx>=2.4 in /usr/local/lib/python3.11/dist-packages (from cirq-core==1.3.0->tensorflow-quantum==0.7.3) (3.4.2)
# Requirement already satisfied: numpy~=1.16 in /usr/local/lib/python3.11/dist-packages (from cirq-core==1.3.0->tensorflow-quantum==0.7.3) (1.26.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from cirq-core==1.3.0->tensorflow-quantum==0.7.3) (2.2.2)
# Collecting sortedcontainers~=2.0 (from cirq-core==1.3.0->tensorflow-quantum==0.7.3)
#   Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from cirq-core==1.3.0->tensorflow-quantum==0.7.3) (1.13.1)
# Requirement already satisfied: typing-extensions>=4.2 in /usr/local/lib/python3.11/dist-packages (from cirq-core==1.3.0->tensorflow-quantum==0.7.3) (4.12.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from cirq-core==1.3.0->tensorflow-quantum==0.7.3) (4.67.1)
# Requirement already satisfied: google-api-core>=1.14.0 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]>=1.14.0->cirq-google==1.3.0->tensorflow-quantum==0.7.3) (2.19.2)
# Requirement already satisfied: proto-plus>=1.20.0 in /usr/local/lib/python3.11/dist-packages (from cirq-google==1.3.0->tensorflow-quantum==0.7.3) (1.25.0)
# Requirement already satisfied: protobuf>=3.15.0 in /usr/local/lib/python3.11/dist-packages (from cirq-google==1.3.0->tensorflow-quantum==0.7.3) (4.25.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.11/dist-packages (from sympy==1.12->tensorflow-quantum==0.7.3) (1.3.0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core>=1.14.0->google-api-core[grpc]>=1.14.0->cirq-google==1.3.0->tensorflow-quantum==0.7.3) (1.66.0)
# Requirement already satisfied: google-auth<3.0.dev0,>=2.14.1 in /usr/local/lib/python3.11/dist-packages (from google-api-core>=1.14.0->google-api-core[grpc]>=1.14.0->cirq-google==1.3.0->tensorflow-quantum==0.7.3) (2.27.0)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /usr/local/lib/python3.11/dist-packages (from google-api-core>=1.14.0->google-api-core[grpc]>=1.14.0->cirq-google==1.3.0->tensorflow-quantum==0.7.3) (2.32.3)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]>=1.14.0->cirq-google==1.3.0->tensorflow-quantum==0.7.3) (1.69.0)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]>=1.14.0->cirq-google==1.3.0->tensorflow-quantum==0.7.3) (1.62.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib~=3.0->cirq-core==1.3.0->tensorflow-quantum==0.7.3) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib~=3.0->cirq-core==1.3.0->tensorflow-quantum==0.7.3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib~=3.0->cirq-core==1.3.0->tensorflow-quantum==0.7.3) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib~=3.0->cirq-core==1.3.0->tensorflow-quantum==0.7.3) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib~=3.0->cirq-core==1.3.0->tensorflow-quantum==0.7.3) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib~=3.0->cirq-core==1.3.0->tensorflow-quantum==0.7.3) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib~=3.0->cirq-core==1.3.0->tensorflow-quantum==0.7.3) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib~=3.0->cirq-core==1.3.0->tensorflow-quantum==0.7.3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->cirq-core==1.3.0->tensorflow-quantum==0.7.3) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->cirq-core==1.3.0->tensorflow-quantum==0.7.3) (2024.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core>=1.14.0->google-api-core[grpc]>=1.14.0->cirq-google==1.3.0->tensorflow-quantum==0.7.3) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core>=1.14.0->google-api-core[grpc]>=1.14.0->cirq-google==1.3.0->tensorflow-quantum==0.7.3) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core>=1.14.0->google-api-core[grpc]>=1.14.0->cirq-google==1.3.0->tensorflow-quantum==0.7.3) (4.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib~=3.0->cirq-core==1.3.0->tensorflow-quantum==0.7.3) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core>=1.14.0->google-api-core[grpc]>=1.14.0->cirq-google==1.3.0->tensorflow-quantum==0.7.3) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core>=1.14.0->google-api-core[grpc]>=1.14.0->cirq-google==1.3.0->tensorflow-quantum==0.7.3) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core>=1.14.0->google-api-core[grpc]>=1.14.0->cirq-google==1.3.0->tensorflow-quantum==0.7.3) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core>=1.14.0->google-api-core[grpc]>=1.14.0->cirq-google==1.3.0->tensorflow-quantum==0.7.3) (2024.12.14)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core>=1.14.0->google-api-core[grpc]>=1.14.0->cirq-google==1.3.0->tensorflow-quantum==0.7.3) (0.6.1)
# Downloading tensorflow_quantum-0.7.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 91.3 MB/s eta 0:00:00
# Downloading cirq_core-1.3.0-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 61.4 MB/s eta 0:00:00
# Downloading cirq_google-1.3.0-py3-none-any.whl (598 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 598.8/598.8 kB 37.9 MB/s eta 0:00:00
# Downloading sympy-1.12-py3-none-any.whl (5.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 79.1 MB/s eta 0:00:00
# Downloading duet-0.2.9-py3-none-any.whl (29 kB)
# Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Installing collected packages: sortedcontainers, sympy, duet, cirq-core, cirq-google, tensorflow-quantum
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.13.1
#     Uninstalling sympy-1.13.1:
#       Successfully uninstalled sympy-1.13.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torch 2.5.1+cu121 requires sympy==1.13.1; python_version >= "3.9", but you have sympy 1.12 which is incompatible.
# Successfully installed cirq-core-1.3.0 cirq-google-1.3.0 duet-0.2.9 sortedcontainers-2.4.0 sympy-1.12 tensorflow-quantum-0.7.3

# %%
import tensorflow as tf
import tensorflow_quantum as tfq
import cirq
import numpy as np
import sympy
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.model_selection import train_test_split

# Load the Fashion MNIST dataset
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# Filter dataset for three classes
selected_classes = [0, 1, 2]  # Modify to include three classes: e.g., 0 = T-shirt/top, 1 = Trouser, 2 = Pullover
train_filter = np.isin(y_train, selected_classes)
test_filter = np.isin(y_test, selected_classes)

x_train, y_train = x_train[train_filter], y_train[train_filter]
x_test, y_test = x_test[test_filter], y_test[test_filter]

# Preprocess the dataset: normalize and downscale
x_train = x_train / 255.0  # Normalize
x_test = x_test / 255.0

class_limit = 500
x_train_limited, y_train_limited = [], []

for cls in selected_classes:
    cls_indices = np.where(y_train == cls)[0][:class_limit]
    x_train_limited.append(x_train[cls_indices])
    y_train_limited.append(y_train[cls_indices])

# Concatenate arrays
x_train_limited = np.concatenate(x_train_limited)
y_train_limited = np.concatenate(y_train_limited)

# Assign back to training set
x_train, y_train = x_train_limited, y_train_limited

# Display shapes of processed datasets
print("Training set shape:", x_train.shape)  # Output: (number_of_samples, 28, 28)
print("Training labels shape:", y_train.shape)  # Output: (number_of_samples,)
print("Test set shape:", x_test.shape)  # Output: (number_of_test_samples, 28, 28)
print("Test labels shape:", y_test.shape)  # Output: (number_of_test_samples,)

# No need to convert labels for binary classification; retain original class labels for multi-class classification

# Further reduce dimensions for quantum efficiency (4x4 grid)
def preprocess_images(images, size=4):
    images = tf.image.resize(images[..., tf.newaxis], (size, size)).numpy()
    return images.reshape(-1, size**2)

x_train = preprocess_images(x_train)
x_test = preprocess_images(x_test)


# Define the quantum circuit
def create_quantum_circuit(qubits, params,layers):
    circuit = cirq.Circuit()
    for layer_num in range(layers):
      for i, qubit in enumerate(qubits):
          circuit.append(cirq.rz(params[i + layer_num] )(qubit))
          circuit.append(cirq.ry(params[i + len(qubits) + layer_num ] )(qubit))
          circuit.append(cirq.rz(params[i + 2*len(qubits) + 3*len(qubits)  + layer_num ])(qubit))
      for i in range(len(qubits) - 1):
          circuit.append(cirq.CZ(qubits[i], qubits[i + 1]))
    return circuit

# Create qubits and symbolic parameters
n_qubits = 16
layers = 3
qubits = [cirq.GridQubit(i, 0) for i in range(n_qubits)]
params = sympy.symbols(f'theta_0:{3*n_qubits*layers }')

# Generate a quantum circuit
example_circuit = create_quantum_circuit(qubits, params,layers)



# Convert circuits to TensorFlow Quantum Tensors



# Convert circuits to TensorFlow Quantum Tensors
def create_quantum_data(images):
    circuits = []
    for image in images:
        circuit = cirq.Circuit()
        for i, pixel in enumerate(image):
            circuit.append(cirq.rx(np.pi * pixel)(qubits[i % n_qubits]))
        circuits.append(circuit)
    return tfq.convert_to_tensor(circuits)

x_train_circuits = create_quantum_data(x_train)
x_test_circuits = create_quantum_data(x_test)


# Define the learning rate schedule
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=0.01, decay_steps=100, decay_rate=0.9
)

# Callbacks
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', patience=5, restore_best_weights=True
)

reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss', factor=0.2, patience=5, min_lr=0.0001
)

# Define the hybrid quantum-classical model using Functional API
def create_model():
    # Input layer
    quantum_input = tf.keras.Input(shape=(), dtype=tf.string, name='quantum_input')

    # Quantum layer
    quantum_layer = tfq.layers.PQC(example_circuit, [cirq.Z(q) for q in qubits])(quantum_input)

    # Dense layer with softmax for multi-class classification
    output = tf.keras.layers.Dense(len(selected_classes), activation="softmax")(quantum_layer)

    # Define the model
    model = tf.keras.Model(inputs=quantum_input, outputs=output, name='Quantum_Classifier')
    return model




model_checkpoint = tf.keras.callbacks.ModelCheckpoint(
    "best_model_mnist_c3_500.h5", monitor="val_loss", save_best_only=True, save_weights_only=True, verbose=1
)

# Create and compile the model
model = create_model()
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=lr_schedule),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)



# Train the model
history = model.fit(
    x_train_circuits, y_train,
    epochs=50,
    batch_size=128,
    validation_split=0.2,
    callbacks=[ model_checkpoint, reduce_lr]
)

# Load the best model weights
# Changed filename to match the one specified in ModelCheckpoint callback
model.load_weights("best_model_mnist_c3_500.h5")

# Evaluate the model
loss, accuracy = model.evaluate(x_test_circuits, y_test)
print(f"Test accuracy: {accuracy:.2f}")

# Plot accuracy and loss
def plot_history(history):
    plt.figure(figsize=(12, 5))

    # Plot accuracy
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title('Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    # Plot loss
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.tight_layout()
    plt.show()

plot_history(history)

# Confusion matrix
y_pred = np.argmax(model.predict(x_test_circuits), axis=1)
cm = confusion_matrix(y_test, y_pred, labels=range(len(selected_classes)))
ConfusionMatrixDisplay(cm, display_labels=selected_classes).plot(cmap='Blues')
plt.title('Confusion Matrix')
plt.show()



# Calculate precision, recall, and F1-score
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')

print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1 Score: {f1:.2f}")
# Out:
# Training set shape: (1500, 28, 28)
# Training labels shape: (1500,)
# Test set shape: (3147, 28, 28)
# Test labels shape: (3147,)
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/initializers/initializers.py:120: UserWarning: The initializer RandomUniform is unseeded and being called multiple times, which will return identical values each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initializer instance more than once.
#   warnings.warn(
# 10/10 [==============================] - ETA: 0s - loss: 1.0192 - accuracy: 0.4375
# Epoch 1: val_loss improved from inf to 1.77439, saving model to best_model_mnist_c3_500.h5
# 10/10 [==============================] - 119s 12s/step - loss: 1.0192 - accuracy: 0.4375 - val_loss: 1.7744 - val_accuracy: 0.0567 - lr: 0.0099
# Epoch 2/50
# 10/10 [==============================] - ETA: 0s - loss: 0.8972 - accuracy: 0.6433
# Epoch 2: val_loss improved from 1.77439 to 1.48482, saving model to best_model_mnist_c3_500.h5
# 10/10 [==============================] - 115s 11s/step - loss: 0.8972 - accuracy: 0.6433 - val_loss: 1.4848 - val_accuracy: 0.2033 - lr: 0.0098
# Epoch 3/50
# 10/10 [==============================] - ETA: 0s - loss: 0.7981 - accuracy: 0.7283
# Epoch 3: val_loss improved from 1.48482 to 1.36568, saving model to best_model_mnist_c3_500.h5
# 10/10 [==============================] - 115s 11s/step - loss: 0.7981 - accuracy: 0.7283 - val_loss: 1.3657 - val_accuracy: 0.3500 - lr: 0.0097
# Epoch 4/50
# 10/10 [==============================] - ETA: 0s - loss: 0.7120 - accuracy: 0.7542
# Epoch 4: val_loss did not improve from 1.36568
# 10/10 [==============================] - 115s 12s/step - loss: 0.7120 - accuracy: 0.7542 - val_loss: 1.3720 - val_accuracy: 0.3700 - lr: 0.0096
# Epoch 5/50
# 10/10 [==============================] - ETA: 0s - loss: 0.6492 - accuracy: 0.7700
# Epoch 5: val_loss improved from 1.36568 to 1.30851, saving model to best_model_mnist_c3_500.h5
# 10/10 [==============================] - 116s 12s/step - loss: 0.6492 - accuracy: 0.7700 - val_loss: 1.3085 - val_accuracy: 0.4567 - lr: 0.0095
# Epoch 6/50
# 10/10 [==============================] - ETA: 0s - loss: 0.6078 - accuracy: 0.7975
# Epoch 6: val_loss improved from 1.30851 to 1.24040, saving model to best_model_mnist_c3_500.h5
# 10/10 [==============================] - 116s 12s/step - loss: 0.6078 - accuracy: 0.7975 - val_loss: 1.2404 - val_accuracy: 0.5433 - lr: 0.0094
# Epoch 7/50
# 10/10 [==============================] - ETA: 0s - loss: 0.5778 - accuracy: 0.8017
# Epoch 7: val_loss did not improve from 1.24040
# 10/10 [==============================] - 120s 12s/step - loss: 0.5778 - accuracy: 0.8017 - val_loss: 1.2472 - val_accuracy: 0.5433 - lr: 0.0093
# Epoch 8/50
# 10/10 [==============================] - ETA: 0s - loss: 0.5566 - accuracy: 0.8033
# Epoch 8: val_loss improved from 1.24040 to 1.22369, saving model to best_model_mnist_c3_500.h5
# 10/10 [==============================] - 117s 12s/step - loss: 0.5566 - accuracy: 0.8033 - val_loss: 1.2237 - val_accuracy: 0.5433 - lr: 0.0092
# Epoch 9/50
# 10/10 [==============================] - ETA: 0s - loss: 0.5431 - accuracy: 0.8092
# Epoch 9: val_loss improved from 1.22369 to 1.20712, saving model to best_model_mnist_c3_500.h5
# 10/10 [==============================] - 120s 12s/step - loss: 0.5431 - accuracy: 0.8092 - val_loss: 1.2071 - val_accuracy: 0.5500 - lr: 0.0091
# Epoch 10/50
# 10/10 [==============================] - ETA: 0s - loss: 0.5329 - accuracy: 0.8142
# Epoch 10: val_loss improved from 1.20712 to 1.14360, saving model to best_model_mnist_c3_500.h5
# 10/10 [==============================] - 115s 11s/step - loss: 0.5329 - accuracy: 0.8142 - val_loss: 1.1436 - val_accuracy: 0.5633 - lr: 0.0090
# Epoch 11/50
# 10/10 [==============================] - ETA: 0s - loss: 0.5228 - accuracy: 0.8158
# Epoch 11: val_loss did not improve from 1.14360
# 10/10 [==============================] - 114s 11s/step - loss: 0.5228 - accuracy: 0.8158 - val_loss: 1.2067 - val_accuracy: 0.5500 - lr: 0.0089
# Epoch 12/50
# 10/10 [==============================] - ETA: 0s - loss: 0.5149 - accuracy: 0.8200
# Epoch 12: val_loss improved from 1.14360 to 1.13753, saving model to best_model_mnist_c3_500.h5
# 10/10 [==============================] - 115s 12s/step - loss: 0.5149 - accuracy: 0.8200 - val_loss: 1.1375 - val_accuracy: 0.5633 - lr: 0.0088
# Epoch 13/50
# 10/10 [==============================] - ETA: 0s - loss: 0.5100 - accuracy: 0.8175
# Epoch 13: val_loss did not improve from 1.13753
# 10/10 [==============================] - 116s 12s/step - loss: 0.5100 - accuracy: 0.8175 - val_loss: 1.1636 - val_accuracy: 0.5500 - lr: 0.0087
# Epoch 14/50
# 10/10 [==============================] - ETA: 0s - loss: 0.5045 - accuracy: 0.8242
# Epoch 14: val_loss improved from 1.13753 to 1.10297, saving model to best_model_mnist_c3_500.h5
# 10/10 [==============================] - 115s 11s/step - loss: 0.5045 - accuracy: 0.8242 - val_loss: 1.1030 - val_accuracy: 0.5767 - lr: 0.0086
# Epoch 15/50
# 10/10 [==============================] - ETA: 0s - loss: 0.5010 - accuracy: 0.8225
# Epoch 15: val_loss did not improve from 1.10297
# 10/10 [==============================] - 116s 12s/step - loss: 0.5010 - accuracy: 0.8225 - val_loss: 1.1058 - val_accuracy: 0.5733 - lr: 0.0085
# Epoch 16/50
# 10/10 [==============================] - ETA: 0s - loss: 0.4952 - accuracy: 0.8233
# Epoch 16: val_loss did not improve from 1.10297
# 10/10 [==============================] - 114s 11s/step - loss: 0.4952 - accuracy: 0.8233 - val_loss: 1.1569 - val_accuracy: 0.5600 - lr: 0.0085
# Epoch 17/50
# 10/10 [==============================] - ETA: 0s - loss: 0.4923 - accuracy: 0.8308
# Epoch 17: val_loss did not improve from 1.10297
# 10/10 [==============================] - 115s 12s/step - loss: 0.4923 - accuracy: 0.8308 - val_loss: 1.1682 - val_accuracy: 0.5600 - lr: 0.0084
# Epoch 18/50
# 10/10 [==============================] - ETA: 0s - loss: 0.4890 - accuracy: 0.8300
# Epoch 18: val_loss did not improve from 1.10297
# 10/10 [==============================] - 115s 12s/step - loss: 0.4890 - accuracy: 0.8300 - val_loss: 1.1335 - val_accuracy: 0.5733 - lr: 0.0083
# Epoch 19/50
# 10/10 [==============================] - ETA: 0s - loss: 0.4848 - accuracy: 0.8300
# Epoch 19: val_loss improved from 1.10297 to 1.10101, saving model to best_model_mnist_c3_500.h5
# 10/10 [==============================] - 117s 12s/step - loss: 0.4848 - accuracy: 0.8300 - val_loss: 1.1010 - val_accuracy: 0.5767 - lr: 0.0082
# Epoch 20/50
# 10/10 [==============================] - ETA: 0s - loss: 0.4821 - accuracy: 0.8342
# Epoch 20: val_loss did not improve from 1.10101
# 10/10 [==============================] - 116s 12s/step - loss: 0.4821 - accuracy: 0.8342 - val_loss: 1.1516 - val_accuracy: 0.5700 - lr: 0.0081
# Epoch 21/50
# 10/10 [==============================] - ETA: 0s - loss: 0.4800 - accuracy: 0.8358
# Epoch 21: val_loss did not improve from 1.10101
# 10/10 [==============================] - 114s 11s/step - loss: 0.4800 - accuracy: 0.8358 - val_loss: 1.1121 - val_accuracy: 0.5867 - lr: 0.0080
# Epoch 22/50
# 10/10 [==============================] - ETA: 0s - loss: 0.4767 - accuracy: 0.8375
# Epoch 22: val_loss improved from 1.10101 to 1.08682, saving model to best_model_mnist_c3_500.h5
# 10/10 [==============================] - 115s 11s/step - loss: 0.4767 - accuracy: 0.8375 - val_loss: 1.0868 - val_accuracy: 0.5867 - lr: 0.0079
# Epoch 23/50
# 10/10 [==============================] - ETA: 0s - loss: 0.4744 - accuracy: 0.8333
# Epoch 23: val_loss did not improve from 1.08682
# 10/10 [==============================] - 115s 12s/step - loss: 0.4744 - accuracy: 0.8333 - val_loss: 1.1833 - val_accuracy: 0.5767 - lr: 0.0079
# Epoch 24/50
# 10/10 [==============================] - ETA: 0s - loss: 0.4716 - accuracy: 0.8367
# Epoch 24: val_loss improved from 1.08682 to 1.06692, saving model to best_model_mnist_c3_500.h5
# 10/10 [==============================] - 116s 12s/step - loss: 0.4716 - accuracy: 0.8367 - val_loss: 1.0669 - val_accuracy: 0.6067 - lr: 0.0078
# Epoch 25/50
# 10/10 [==============================] - ETA: 0s - loss: 0.4687 - accuracy: 0.8367
# Epoch 25: val_loss did not improve from 1.06692
# 10/10 [==============================] - 116s 12s/step - loss: 0.4687 - accuracy: 0.8367 - val_loss: 1.1026 - val_accuracy: 0.6033 - lr: 0.0077
# Epoch 26/50
# 10/10 [==============================] - ETA: 0s - loss: 0.4662 - accuracy: 0.8417
# Epoch 26: val_loss did not improve from 1.06692
# 10/10 [==============================] - 116s 11s/step - loss: 0.4662 - accuracy: 0.8417 - val_loss: 1.1022 - val_accuracy: 0.6033 - lr: 0.0076
# Epoch 27/50
# 10/10 [==============================] - ETA: 0s - loss: 0.4638 - accuracy: 0.8383
# Epoch 27: val_loss did not improve from 1.06692
# 10/10 [==============================] - 114s 11s/step - loss: 0.4638 - accuracy: 0.8383 - val_loss: 1.1244 - val_accuracy: 0.6033 - lr: 0.0075
# Epoch 28/50
# 10/10 [==============================] - ETA: 0s - loss: 0.4611 - accuracy: 0.8425
# Epoch 28: val_loss improved from 1.06692 to 1.05750, saving model to best_model_mnist_c3_500.h5
# 10/10 [==============================] - 116s 12s/step - loss: 0.4611 - accuracy: 0.8425 - val_loss: 1.0575 - val_accuracy: 0.6167 - lr: 0.0075
# Epoch 29/50
# 10/10 [==============================] - ETA: 0s - loss: 0.4593 - accuracy: 0.8400
# Epoch 29: val_loss did not improve from 1.05750
# 10/10 [==============================] - 116s 12s/step - loss: 0.4593 - accuracy: 0.8400 - val_loss: 1.1575 - val_accuracy: 0.5967 - lr: 0.0074
# Epoch 30/50
# 10/10 [==============================] - ETA: 0s - loss: 0.4562 - accuracy: 0.8425
# Epoch 30: val_loss improved from 1.05750 to 1.03058, saving model to best_model_mnist_c3_500.h5
# 10/10 [==============================] - 116s 12s/step - loss: 0.4562 - accuracy: 0.8425 - val_loss: 1.0306 - val_accuracy: 0.6300 - lr: 0.0073
# Epoch 31/50
# 10/10 [==============================] - ETA: 0s - loss: 0.4559 - accuracy: 0.8467
# Epoch 31: val_loss did not improve from 1.03058
# 10/10 [==============================] - 120s 12s/step - loss: 0.4559 - accuracy: 0.8467 - val_loss: 1.1219 - val_accuracy: 0.5833 - lr: 0.0072
# Epoch 32/50
# 10/10 [==============================] - ETA: 0s - loss: 0.4535 - accuracy: 0.8400
# Epoch 32: val_loss did not improve from 1.03058
# 10/10 [==============================] - 114s 11s/step - loss: 0.4535 - accuracy: 0.8400 - val_loss: 1.0502 - val_accuracy: 0.6267 - lr: 0.0071
# Epoch 33/50
# 10/10 [==============================] - ETA: 0s - loss: 0.4512 - accuracy: 0.8433
# Epoch 33: val_loss did not improve from 1.03058
# 10/10 [==============================] - 115s 12s/step - loss: 0.4512 - accuracy: 0.8433 - val_loss: 1.1203 - val_accuracy: 0.5867 - lr: 0.0071
# Epoch 34/50
# 10/10 [==============================] - ETA: 0s - loss: 0.4530 - accuracy: 0.8400
# Epoch 34: val_loss did not improve from 1.03058
# 10/10 [==============================] - 114s 11s/step - loss: 0.4530 - accuracy: 0.8400 - val_loss: 1.1433 - val_accuracy: 0.5733 - lr: 0.0070
# Epoch 35/50
# 10/10 [==============================] - ETA: 0s - loss: 0.4525 - accuracy: 0.8367
# Epoch 35: val_loss improved from 1.03058 to 0.99733, saving model to best_model_mnist_c3_500.h5
# 10/10 [==============================] - 115s 11s/step - loss: 0.4525 - accuracy: 0.8367 - val_loss: 0.9973 - val_accuracy: 0.6367 - lr: 0.0069
# Epoch 36/50
# 10/10 [==============================] - ETA: 0s - loss: 0.4492 - accuracy: 0.8433
# Epoch 36: val_loss did not improve from 0.99733
# 10/10 [==============================] - 114s 11s/step - loss: 0.4492 - accuracy: 0.8433 - val_loss: 1.1680 - val_accuracy: 0.5633 - lr: 0.0069
# Epoch 37/50
# 10/10 [==============================] - ETA: 0s - loss: 0.4476 - accuracy: 0.8467
# Epoch 37: val_loss did not improve from 0.99733
# 10/10 [==============================] - 113s 11s/step - loss: 0.4476 - accuracy: 0.8467 - val_loss: 1.0955 - val_accuracy: 0.5733 - lr: 0.0068
# Epoch 38/50
# 10/10 [==============================] - ETA: 0s - loss: 0.4483 - accuracy: 0.8433
# Epoch 38: val_loss did not improve from 0.99733
# 10/10 [==============================] - 115s 11s/step - loss: 0.4483 - accuracy: 0.8433 - val_loss: 1.0129 - val_accuracy: 0.6233 - lr: 0.0067
# Epoch 39/50
# 10/10 [==============================] - ETA: 0s - loss: 0.4472 - accuracy: 0.8392
# Epoch 39: val_loss did not improve from 0.99733
# 10/10 [==============================] - 115s 11s/step - loss: 0.4472 - accuracy: 0.8392 - val_loss: 1.1619 - val_accuracy: 0.5667 - lr: 0.0066
# Epoch 40/50
# 10/10 [==============================] - ETA: 0s - loss: 0.4452 - accuracy: 0.8492
# Epoch 40: val_loss did not improve from 0.99733
# 10/10 [==============================] - 119s 12s/step - loss: 0.4452 - accuracy: 0.8492 - val_loss: 1.0697 - val_accuracy: 0.5800 - lr: 0.0066
# Epoch 41/50
# 10/10 [==============================] - ETA: 0s - loss: 0.4445 - accuracy: 0.8442
# Epoch 41: val_loss did not improve from 0.99733
# 10/10 [==============================] - 114s 11s/step - loss: 0.4445 - accuracy: 0.8442 - val_loss: 1.0505 - val_accuracy: 0.5867 - lr: 0.0065
# Epoch 42/50
# 10/10 [==============================] - ETA: 0s - loss: 0.4437 - accuracy: 0.8458
# Epoch 42: val_loss did not improve from 0.99733
# 10/10 [==============================] - 115s 11s/step - loss: 0.4437 - accuracy: 0.8458 - val_loss: 1.1285 - val_accuracy: 0.5733 - lr: 0.0064
# Epoch 43/50
# 10/10 [==============================] - ETA: 0s - loss: 0.4443 - accuracy: 0.8417
# Epoch 43: val_loss did not improve from 0.99733
# 10/10 [==============================] - 117s 12s/step - loss: 0.4443 - accuracy: 0.8417 - val_loss: 1.0911 - val_accuracy: 0.5733 - lr: 0.0064
# Epoch 44/50
# 10/10 [==============================] - ETA: 0s - loss: 0.4422 - accuracy: 0.8492
# Epoch 44: val_loss did not improve from 0.99733
# 10/10 [==============================] - 113s 11s/step - loss: 0.4422 - accuracy: 0.8492 - val_loss: 1.0855 - val_accuracy: 0.5733 - lr: 0.0063
# Epoch 45/50
# 10/10 [==============================] - ETA: 0s - loss: 0.4416 - accuracy: 0.8458
# Epoch 45: val_loss did not improve from 0.99733
# 10/10 [==============================] - 113s 11s/step - loss: 0.4416 - accuracy: 0.8458 - val_loss: 1.0742 - val_accuracy: 0.5767 - lr: 0.0062
# Epoch 46/50
# 10/10 [==============================] - ETA: 0s - loss: 0.4412 - accuracy: 0.8475
# Epoch 46: val_loss did not improve from 0.99733
# 10/10 [==============================] - 113s 11s/step - loss: 0.4412 - accuracy: 0.8475 - val_loss: 1.0656 - val_accuracy: 0.5733 - lr: 0.0062
# Epoch 47/50
# 10/10 [==============================] - ETA: 0s - loss: 0.4404 - accuracy: 0.8500
# Epoch 47: val_loss did not improve from 0.99733
# 10/10 [==============================] - 113s 11s/step - loss: 0.4404 - accuracy: 0.8500 - val_loss: 1.0824 - val_accuracy: 0.5767 - lr: 0.0061
# Epoch 48/50
# 10/10 [==============================] - ETA: 0s - loss: 0.4408 - accuracy: 0.8450
# Epoch 48: val_loss did not improve from 0.99733
# 10/10 [==============================] - 118s 12s/step - loss: 0.4408 - accuracy: 0.8450 - val_loss: 1.0922 - val_accuracy: 0.5733 - lr: 0.0060
# Epoch 49/50
# 10/10 [==============================] - ETA: 0s - loss: 0.4404 - accuracy: 0.8492
# Epoch 49: val_loss did not improve from 0.99733
# 10/10 [==============================] - 114s 11s/step - loss: 0.4404 - accuracy: 0.8492 - val_loss: 0.9983 - val_accuracy: 0.5967 - lr: 0.0060
# Epoch 50/50
# 10/10 [==============================] - ETA: 0s - loss: 0.4391 - accuracy: 0.8517
# Epoch 50: val_loss did not improve from 0.99733
# 10/10 [==============================] - 113s 11s/step - loss: 0.4391 - accuracy: 0.8517 - val_loss: 1.1061 - val_accuracy: 0.5733 - lr: 0.0059
# 99/99 [==============================] - 42s 427ms/step - loss: 0.5992 - accuracy: 0.7871
# Test accuracy: 0.79
# 99/99 [==============================] - 43s 432ms/step
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-b9249119898c> in <cell line: 0>()
#     196
#     197 # Calculate precision, recall, and F1-score
# --> 198 precision = precision_score(y_test, y_pred, average='weighted')
#     199 recall = recall_score(y_test, y_pred, average='weighted')
#     200 f1 = f1_score(y_test, y_pred, average='weighted')
#
# NameError: name 'precision_score' is not defined

# %%
import tensorflow as tf
import tensorflow_quantum as tfq
import cirq
import numpy as np
import sympy
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.model_selection import train_test_split

# Load the Fashion MNIST dataset
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# Filter dataset for three classes
selected_classes = [0, 1, 2]  # Modify to include three classes: e.g., 0 = T-shirt/top, 1 = Trouser, 2 = Pullover
train_filter = np.isin(y_train, selected_classes)
test_filter = np.isin(y_test, selected_classes)

x_train, y_train = x_train[train_filter], y_train[train_filter]
x_test, y_test = x_test[test_filter], y_test[test_filter]

# Preprocess the dataset: normalize and downscale
x_train = x_train / 255.0  # Normalize
x_test = x_test / 255.0

class_limit = 1000
x_train_limited, y_train_limited = [], []

for cls in selected_classes:
    cls_indices = np.where(y_train == cls)[0][:class_limit]
    x_train_limited.append(x_train[cls_indices])
    y_train_limited.append(y_train[cls_indices])

# Concatenate arrays
x_train_limited = np.concatenate(x_train_limited)
y_train_limited = np.concatenate(y_train_limited)

# Assign back to training set
x_train, y_train = x_train_limited, y_train_limited

# Display shapes of processed datasets
print("Training set shape:", x_train.shape)  # Output: (number_of_samples, 28, 28)
print("Training labels shape:", y_train.shape)  # Output: (number_of_samples,)
print("Test set shape:", x_test.shape)  # Output: (number_of_test_samples, 28, 28)
print("Test labels shape:", y_test.shape)  # Output: (number_of_test_samples,)

# No need to convert labels for binary classification; retain original class labels for multi-class classification

# Further reduce dimensions for quantum efficiency (4x4 grid)
def preprocess_images(images, size=4):
    images = tf.image.resize(images[..., tf.newaxis], (size, size)).numpy()
    return images.reshape(-1, size**2)

x_train = preprocess_images(x_train)
x_test = preprocess_images(x_test)


# Define the quantum circuit
def create_quantum_circuit(qubits, params,layers):
    circuit = cirq.Circuit()
    for layer_num in range(layers):
      for i, qubit in enumerate(qubits):
          circuit.append(cirq.rz(params[i + layer_num] )(qubit))
          circuit.append(cirq.ry(params[i + len(qubits) + layer_num ] )(qubit))
          circuit.append(cirq.rz(params[i + 2*len(qubits) + 3*len(qubits)  + layer_num ])(qubit))
      for i in range(len(qubits) - 1):
          circuit.append(cirq.CZ(qubits[i], qubits[i + 1]))
    return circuit

# Create qubits and symbolic parameters
n_qubits = 16
layers = 3
qubits = [cirq.GridQubit(i, 0) for i in range(n_qubits)]
params = sympy.symbols(f'theta_0:{3*n_qubits*layers }')

# Generate a quantum circuit
example_circuit = create_quantum_circuit(qubits, params,layers)



# Convert circuits to TensorFlow Quantum Tensors



# Convert circuits to TensorFlow Quantum Tensors
def create_quantum_data(images):
    circuits = []
    for image in images:
        circuit = cirq.Circuit()
        for i, pixel in enumerate(image):
            circuit.append(cirq.rx(np.pi * pixel)(qubits[i % n_qubits]))
        circuits.append(circuit)
    return tfq.convert_to_tensor(circuits)

x_train_circuits = create_quantum_data(x_train)
x_test_circuits = create_quantum_data(x_test)


# Define the learning rate schedule
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=0.01, decay_steps=100, decay_rate=0.9
)

# Callbacks
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', patience=5, restore_best_weights=True
)

reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss', factor=0.2, patience=5, min_lr=0.0001
)

# Define the hybrid quantum-classical model using Functional API
def create_model():
    # Input layer
    quantum_input = tf.keras.Input(shape=(), dtype=tf.string, name='quantum_input')

    # Quantum layer
    quantum_layer = tfq.layers.PQC(example_circuit, [cirq.Z(q) for q in qubits])(quantum_input)

    # Dense layer with softmax for multi-class classification
    output = tf.keras.layers.Dense(len(selected_classes), activation="softmax")(quantum_layer)

    # Define the model
    model = tf.keras.Model(inputs=quantum_input, outputs=output, name='Quantum_Classifier')
    return model




model_checkpoint = tf.keras.callbacks.ModelCheckpoint(
    "best_model_mnist_c3_1000.h5", monitor="val_loss", save_best_only=True, save_weights_only=True, verbose=1
)

# Create and compile the model
model = create_model()
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=lr_schedule),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)



# Train the model
history = model.fit(
    x_train_circuits, y_train,
    epochs=50,
    batch_size=128,
    validation_split=0.2,
    callbacks=[ model_checkpoint, reduce_lr]
)

# Load the best model weights
# Changed filename to match the one specified in ModelCheckpoint callback
model.load_weights("best_model_mnist_c3_1000.h5")

# Evaluate the model
loss, accuracy = model.evaluate(x_test_circuits, y_test)
print(f"Test accuracy: {accuracy:.2f}")

# Plot accuracy and loss
def plot_history(history):
    plt.figure(figsize=(12, 5))

    # Plot accuracy
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title('Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    # Plot loss
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.tight_layout()
    plt.show()

plot_history(history)

# Confusion matrix
y_pred = np.argmax(model.predict(x_test_circuits), axis=1)
cm = confusion_matrix(y_test, y_pred, labels=range(len(selected_classes)))
ConfusionMatrixDisplay(cm, display_labels=selected_classes).plot(cmap='Blues')
plt.title('Confusion Matrix')
plt.show()



# Calculate precision, recall, and F1-score
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')

print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1 Score: {f1:.2f}")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# Training set shape: (3000, 28, 28)
# Training labels shape: (3000,)
# Test set shape: (3147, 28, 28)
# Test labels shape: (3147,)
# Epoch 1/50
# 19/19 [==============================] - ETA: 0s - loss: 1.0720 - accuracy: 0.4708
# Epoch 1: val_loss improved from inf to 1.87302, saving model to best_model_mnist_c3_1000.h5
# 19/19 [==============================] - 235s 12s/step - loss: 1.0720 - accuracy: 0.4708 - val_loss: 1.8730 - val_accuracy: 0.0500 - lr: 0.0098
# Epoch 2/50
# 19/19 [==============================] - ETA: 0s - loss: 0.8311 - accuracy: 0.6787
# Epoch 2: val_loss improved from 1.87302 to 1.82402, saving model to best_model_mnist_c3_1000.h5
# 19/19 [==============================] - 236s 12s/step - loss: 0.8311 - accuracy: 0.6787 - val_loss: 1.8240 - val_accuracy: 0.0433 - lr: 0.0096
# Epoch 3/50
# 19/19 [==============================] - ETA: 0s - loss: 0.7078 - accuracy: 0.7079
# Epoch 3: val_loss improved from 1.82402 to 1.44390, saving model to best_model_mnist_c3_1000.h5
# 19/19 [==============================] - 235s 12s/step - loss: 0.7078 - accuracy: 0.7079 - val_loss: 1.4439 - val_accuracy: 0.2000 - lr: 0.0094
# Epoch 4/50
# 19/19 [==============================] - ETA: 0s - loss: 0.6248 - accuracy: 0.7596
# Epoch 4: val_loss improved from 1.44390 to 1.39077, saving model to best_model_mnist_c3_1000.h5
# 19/19 [==============================] - 235s 12s/step - loss: 0.6248 - accuracy: 0.7596 - val_loss: 1.3908 - val_accuracy: 0.2800 - lr: 0.0092
# Epoch 5/50
# 19/19 [==============================] - ETA: 0s - loss: 0.5771 - accuracy: 0.7846
# Epoch 5: val_loss improved from 1.39077 to 1.31932, saving model to best_model_mnist_c3_1000.h5
# 19/19 [==============================] - 240s 13s/step - loss: 0.5771 - accuracy: 0.7846 - val_loss: 1.3193 - val_accuracy: 0.4633 - lr: 0.0091
# Epoch 6/50
# 19/19 [==============================] - ETA: 0s - loss: 0.5487 - accuracy: 0.8033
# Epoch 6: val_loss improved from 1.31932 to 1.28282, saving model to best_model_mnist_c3_1000.h5
# 19/19 [==============================] - 235s 12s/step - loss: 0.5487 - accuracy: 0.8033 - val_loss: 1.2828 - val_accuracy: 0.5283 - lr: 0.0089
# Epoch 7/50
# 19/19 [==============================] - ETA: 0s - loss: 0.5309 - accuracy: 0.8100
# Epoch 7: val_loss improved from 1.28282 to 1.26031, saving model to best_model_mnist_c3_1000.h5
# 19/19 [==============================] - 239s 13s/step - loss: 0.5309 - accuracy: 0.8100 - val_loss: 1.2603 - val_accuracy: 0.5433 - lr: 0.0087
# Epoch 8/50
# 19/19 [==============================] - ETA: 0s - loss: 0.5193 - accuracy: 0.8129
# Epoch 8: val_loss improved from 1.26031 to 1.22709, saving model to best_model_mnist_c3_1000.h5
# 19/19 [==============================] - 235s 12s/step - loss: 0.5193 - accuracy: 0.8129 - val_loss: 1.2271 - val_accuracy: 0.5567 - lr: 0.0085
# Epoch 9/50
# 19/19 [==============================] - ETA: 0s - loss: 0.5115 - accuracy: 0.8146
# Epoch 9: val_loss improved from 1.22709 to 1.21192, saving model to best_model_mnist_c3_1000.h5
# 19/19 [==============================] - 235s 12s/step - loss: 0.5115 - accuracy: 0.8146 - val_loss: 1.2119 - val_accuracy: 0.5517 - lr: 0.0084
# Epoch 10/50
# 19/19 [==============================] - ETA: 0s - loss: 0.5032 - accuracy: 0.8167
# Epoch 10: val_loss improved from 1.21192 to 1.20435, saving model to best_model_mnist_c3_1000.h5
# 19/19 [==============================] - 234s 12s/step - loss: 0.5032 - accuracy: 0.8167 - val_loss: 1.2044 - val_accuracy: 0.5717 - lr: 0.0082
# Epoch 11/50
# 19/19 [==============================] - ETA: 0s - loss: 0.4976 - accuracy: 0.8225
# Epoch 11: val_loss did not improve from 1.20435
# 19/19 [==============================] - 234s 12s/step - loss: 0.4976 - accuracy: 0.8225 - val_loss: 1.2507 - val_accuracy: 0.5533 - lr: 0.0080
# Epoch 12/50
# 19/19 [==============================] - ETA: 0s - loss: 0.4936 - accuracy: 0.8233
# Epoch 12: val_loss improved from 1.20435 to 1.19863, saving model to best_model_mnist_c3_1000.h5
# 19/19 [==============================] - 234s 12s/step - loss: 0.4936 - accuracy: 0.8233 - val_loss: 1.1986 - val_accuracy: 0.5750 - lr: 0.0079
# Epoch 13/50
# 19/19 [==============================] - ETA: 0s - loss: 0.4905 - accuracy: 0.8354
# Epoch 13: val_loss improved from 1.19863 to 1.18034, saving model to best_model_mnist_c3_1000.h5
# 19/19 [==============================] - 237s 13s/step - loss: 0.4905 - accuracy: 0.8354 - val_loss: 1.1803 - val_accuracy: 0.5867 - lr: 0.0077
# Epoch 14/50
# 19/19 [==============================] - ETA: 0s - loss: 0.4859 - accuracy: 0.8317
# Epoch 14: val_loss improved from 1.18034 to 1.16886, saving model to best_model_mnist_c3_1000.h5
# 19/19 [==============================] - 232s 12s/step - loss: 0.4859 - accuracy: 0.8317 - val_loss: 1.1689 - val_accuracy: 0.5767 - lr: 0.0076
# Epoch 15/50
# 19/19 [==============================] - ETA: 0s - loss: 0.4842 - accuracy: 0.8342
# Epoch 15: val_loss did not improve from 1.16886
# 19/19 [==============================] - 232s 12s/step - loss: 0.4842 - accuracy: 0.8342 - val_loss: 1.1967 - val_accuracy: 0.5533 - lr: 0.0074
# Epoch 16/50
# 19/19 [==============================] - ETA: 0s - loss: 0.4811 - accuracy: 0.8371
# Epoch 16: val_loss did not improve from 1.16886
# 19/19 [==============================] - 232s 12s/step - loss: 0.4811 - accuracy: 0.8371 - val_loss: 1.2309 - val_accuracy: 0.5433 - lr: 0.0073
# Epoch 17/50
# 19/19 [==============================] - ETA: 0s - loss: 0.4792 - accuracy: 0.8371
# Epoch 17: val_loss did not improve from 1.16886
# 19/19 [==============================] - 233s 12s/step - loss: 0.4792 - accuracy: 0.8371 - val_loss: 1.1805 - val_accuracy: 0.5800 - lr: 0.0071
# Epoch 18/50
# 19/19 [==============================] - ETA: 0s - loss: 0.4775 - accuracy: 0.8379
# Epoch 18: val_loss did not improve from 1.16886
# 19/19 [==============================] - 232s 12s/step - loss: 0.4775 - accuracy: 0.8379 - val_loss: 1.1831 - val_accuracy: 0.5500 - lr: 0.0070
# Epoch 19/50
# 19/19 [==============================] - ETA: 0s - loss: 0.4752 - accuracy: 0.8375
# Epoch 19: val_loss improved from 1.16886 to 1.12627, saving model to best_model_mnist_c3_1000.h5
# 19/19 [==============================] - 231s 12s/step - loss: 0.4752 - accuracy: 0.8375 - val_loss: 1.1263 - val_accuracy: 0.5550 - lr: 0.0068
# Epoch 20/50
# 19/19 [==============================] - ETA: 0s - loss: 0.4726 - accuracy: 0.8408
# Epoch 20: val_loss did not improve from 1.12627
# 19/19 [==============================] - 233s 12s/step - loss: 0.4726 - accuracy: 0.8408 - val_loss: 1.1919 - val_accuracy: 0.5483 - lr: 0.0067
# Epoch 21/50
# 19/19 [==============================] - ETA: 0s - loss: 0.4716 - accuracy: 0.8363
# Epoch 21: val_loss did not improve from 1.12627
# 19/19 [==============================] - 229s 12s/step - loss: 0.4716 - accuracy: 0.8363 - val_loss: 1.1550 - val_accuracy: 0.5483 - lr: 0.0066
# Epoch 22/50
# 19/19 [==============================] - ETA: 0s - loss: 0.4698 - accuracy: 0.8408
# Epoch 22: val_loss did not improve from 1.12627
# 19/19 [==============================] - 233s 12s/step - loss: 0.4698 - accuracy: 0.8408 - val_loss: 1.1999 - val_accuracy: 0.5417 - lr: 0.0064
# Epoch 23/50
# 19/19 [==============================] - ETA: 0s - loss: 0.4677 - accuracy: 0.8421
# Epoch 23: val_loss did not improve from 1.12627
# 19/19 [==============================] - 233s 12s/step - loss: 0.4677 - accuracy: 0.8421 - val_loss: 1.1562 - val_accuracy: 0.5550 - lr: 0.0063
# Epoch 24/50
# 19/19 [==============================] - ETA: 0s - loss: 0.4658 - accuracy: 0.8408
# Epoch 24: val_loss did not improve from 1.12627
# 19/19 [==============================] - 232s 12s/step - loss: 0.4658 - accuracy: 0.8408 - val_loss: 1.1770 - val_accuracy: 0.5367 - lr: 0.0062
# Epoch 25/50
# 19/19 [==============================] - ETA: 0s - loss: 0.4661 - accuracy: 0.8417
# Epoch 25: val_loss did not improve from 1.12627
# 19/19 [==============================] - 231s 12s/step - loss: 0.4661 - accuracy: 0.8417 - val_loss: 1.1844 - val_accuracy: 0.5417 - lr: 0.0061
# Epoch 26/50
# 19/19 [==============================] - ETA: 0s - loss: 0.4647 - accuracy: 0.8417
# Epoch 26: val_loss did not improve from 1.12627
# 19/19 [==============================] - 229s 12s/step - loss: 0.4647 - accuracy: 0.8417 - val_loss: 1.2030 - val_accuracy: 0.5333 - lr: 0.0059
# Epoch 27/50
# 19/19 [==============================] - ETA: 0s - loss: 0.4622 - accuracy: 0.8417
# Epoch 27: val_loss did not improve from 1.12627
# 19/19 [==============================] - 229s 12s/step - loss: 0.4622 - accuracy: 0.8417 - val_loss: 1.1666 - val_accuracy: 0.5433 - lr: 0.0058
# Epoch 28/50
# 19/19 [==============================] - ETA: 0s - loss: 0.4603 - accuracy: 0.8446
# Epoch 28: val_loss did not improve from 1.12627
# 19/19 [==============================] - 230s 12s/step - loss: 0.4603 - accuracy: 0.8446 - val_loss: 1.1488 - val_accuracy: 0.5517 - lr: 0.0057
# Epoch 29/50
# 19/19 [==============================] - ETA: 0s - loss: 0.4599 - accuracy: 0.8417
# Epoch 29: val_loss did not improve from 1.12627
# 19/19 [==============================] - 231s 12s/step - loss: 0.4599 - accuracy: 0.8417 - val_loss: 1.1893 - val_accuracy: 0.5350 - lr: 0.0056
# Epoch 30/50
# 19/19 [==============================] - ETA: 0s - loss: 0.4593 - accuracy: 0.8442
# Epoch 30: val_loss did not improve from 1.12627
# 19/19 [==============================] - 232s 12s/step - loss: 0.4593 - accuracy: 0.8442 - val_loss: 1.1539 - val_accuracy: 0.5750 - lr: 0.0055
# Epoch 31/50
# 19/19 [==============================] - ETA: 0s - loss: 0.4585 - accuracy: 0.8433
# Epoch 31: val_loss did not improve from 1.12627
# 19/19 [==============================] - 231s 12s/step - loss: 0.4585 - accuracy: 0.8433 - val_loss: 1.2112 - val_accuracy: 0.5200 - lr: 0.0054
# Epoch 32/50
# 19/19 [==============================] - ETA: 0s - loss: 0.4602 - accuracy: 0.8446
# Epoch 32: val_loss improved from 1.12627 to 1.12522, saving model to best_model_mnist_c3_1000.h5
# 19/19 [==============================] - 230s 12s/step - loss: 0.4602 - accuracy: 0.8446 - val_loss: 1.1252 - val_accuracy: 0.5550 - lr: 0.0053
# Epoch 33/50
# 19/19 [==============================] - ETA: 0s - loss: 0.4571 - accuracy: 0.8421
# Epoch 33: val_loss did not improve from 1.12522
# 19/19 [==============================] - 230s 12s/step - loss: 0.4571 - accuracy: 0.8421 - val_loss: 1.1439 - val_accuracy: 0.5433 - lr: 0.0052
# Epoch 34/50
# 19/19 [==============================] - ETA: 0s - loss: 0.4562 - accuracy: 0.8442
# Epoch 34: val_loss did not improve from 1.12522
# 19/19 [==============================] - 231s 12s/step - loss: 0.4562 - accuracy: 0.8442 - val_loss: 1.1655 - val_accuracy: 0.5450 - lr: 0.0051
# Epoch 35/50
# 19/19 [==============================] - ETA: 0s - loss: 0.4554 - accuracy: 0.8442
# Epoch 35: val_loss did not improve from 1.12522
# 19/19 [==============================] - 229s 12s/step - loss: 0.4554 - accuracy: 0.8442 - val_loss: 1.1533 - val_accuracy: 0.5450 - lr: 0.0050
# Epoch 36/50
# 19/19 [==============================] - ETA: 0s - loss: 0.4546 - accuracy: 0.8442
# Epoch 36: val_loss did not improve from 1.12522
# 19/19 [==============================] - 230s 12s/step - loss: 0.4546 - accuracy: 0.8442 - val_loss: 1.1546 - val_accuracy: 0.5467 - lr: 0.0049
# Epoch 37/50
# 19/19 [==============================] - ETA: 0s - loss: 0.4535 - accuracy: 0.8475
# Epoch 37: val_loss did not improve from 1.12522
# 19/19 [==============================] - 228s 12s/step - loss: 0.4535 - accuracy: 0.8475 - val_loss: 1.1344 - val_accuracy: 0.5550 - lr: 0.0048
# Epoch 38/50
# 19/19 [==============================] - ETA: 0s - loss: 0.4549 - accuracy: 0.8442
# Epoch 38: val_loss did not improve from 1.12522
# 19/19 [==============================] - 230s 12s/step - loss: 0.4549 - accuracy: 0.8442 - val_loss: 1.1846 - val_accuracy: 0.5233 - lr: 0.0047
# Epoch 39/50
# 19/19 [==============================] - ETA: 0s - loss: 0.4527 - accuracy: 0.8450
# Epoch 39: val_loss did not improve from 1.12522
# 19/19 [==============================] - 229s 12s/step - loss: 0.4527 - accuracy: 0.8450 - val_loss: 1.1550 - val_accuracy: 0.5400 - lr: 0.0046
# Epoch 40/50
# 19/19 [==============================] - ETA: 0s - loss: 0.4528 - accuracy: 0.8454
# Epoch 40: val_loss did not improve from 1.12522
# 19/19 [==============================] - 225s 12s/step - loss: 0.4528 - accuracy: 0.8454 - val_loss: 1.1679 - val_accuracy: 0.5283 - lr: 0.0045
# Epoch 41/50
# 19/19 [==============================] - ETA: 0s - loss: 0.4515 - accuracy: 0.8446
# Epoch 41: val_loss improved from 1.12522 to 1.10056, saving model to best_model_mnist_c3_1000.h5
# 19/19 [==============================] - 228s 12s/step - loss: 0.4515 - accuracy: 0.8446 - val_loss: 1.1006 - val_accuracy: 0.5667 - lr: 0.0044
# Epoch 42/50
# 19/19 [==============================] - ETA: 0s - loss: 0.4524 - accuracy: 0.8471
# Epoch 42: val_loss did not improve from 1.10056
# 19/19 [==============================] - 228s 12s/step - loss: 0.4524 - accuracy: 0.8471 - val_loss: 1.1450 - val_accuracy: 0.5450 - lr: 0.0043
# Epoch 43/50
# 19/19 [==============================] - ETA: 0s - loss: 0.4514 - accuracy: 0.8458
# Epoch 43: val_loss did not improve from 1.10056
# 19/19 [==============================] - 227s 12s/step - loss: 0.4514 - accuracy: 0.8458 - val_loss: 1.1612 - val_accuracy: 0.5383 - lr: 0.0042
# Epoch 44/50
# 19/19 [==============================] - ETA: 0s - loss: 0.4511 - accuracy: 0.8429
# Epoch 44: val_loss did not improve from 1.10056
# 19/19 [==============================] - 231s 12s/step - loss: 0.4511 - accuracy: 0.8429 - val_loss: 1.1242 - val_accuracy: 0.5600 - lr: 0.0041
# Epoch 45/50
# 19/19 [==============================] - ETA: 0s - loss: 0.4510 - accuracy: 0.8471
# Epoch 45: val_loss did not improve from 1.10056
# 19/19 [==============================] - 228s 12s/step - loss: 0.4510 - accuracy: 0.8471 - val_loss: 1.1464 - val_accuracy: 0.5400 - lr: 0.0041
# Epoch 46/50
# 19/19 [==============================] - ETA: 0s - loss: 0.4512 - accuracy: 0.8417
# Epoch 46: val_loss did not improve from 1.10056
# 19/19 [==============================] - 226s 12s/step - loss: 0.4512 - accuracy: 0.8417 - val_loss: 1.1431 - val_accuracy: 0.5400 - lr: 0.0040
# Epoch 47/50
# 19/19 [==============================] - ETA: 0s - loss: 0.4494 - accuracy: 0.8479
# Epoch 47: val_loss did not improve from 1.10056
# 19/19 [==============================] - 228s 12s/step - loss: 0.4494 - accuracy: 0.8479 - val_loss: 1.1295 - val_accuracy: 0.5500 - lr: 0.0039
# Epoch 48/50
# 19/19 [==============================] - ETA: 0s - loss: 0.4488 - accuracy: 0.8471
# Epoch 48: val_loss did not improve from 1.10056
# 19/19 [==============================] - 229s 12s/step - loss: 0.4488 - accuracy: 0.8471 - val_loss: 1.1325 - val_accuracy: 0.5417 - lr: 0.0038
# Epoch 49/50
# 19/19 [==============================] - ETA: 0s - loss: 0.4487 - accuracy: 0.8475
# Epoch 49: val_loss did not improve from 1.10056
# 19/19 [==============================] - 229s 12s/step - loss: 0.4487 - accuracy: 0.8475 - val_loss: 1.1405 - val_accuracy: 0.5433 - lr: 0.0038
# Epoch 50/50
# 19/19 [==============================] - ETA: 0s - loss: 0.4484 - accuracy: 0.8450
# Epoch 50: val_loss did not improve from 1.10056
# 19/19 [==============================] - 228s 12s/step - loss: 0.4484 - accuracy: 0.8450 - val_loss: 1.1394 - val_accuracy: 0.5400 - lr: 0.0037
# 99/99 [==============================] - 42s 425ms/step - loss: 0.6091 - accuracy: 0.7814
# Test accuracy: 0.78
# 99/99 [==============================] - 43s 428ms/step
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-ecfce10fa75f> in <cell line: 0>()
#     196
#     197 # Calculate precision, recall, and F1-score
# --> 198 precision = precision_score(y_test, y_pred, average='weighted')
#     199 recall = recall_score(y_test, y_pred, average='weighted')
#     200 f1 = f1_score(y_test, y_pred, average='weighted')
#
# NameError: name 'precision_score' is not defined
